# %% [markdown]
# # OPEN STREET MAP CASE STUDY PROJECT

# %% [markdown]
# MAP AREA
# San Francisco, CA, USA
#
# https://mapzen.com/data/metro-extracts/your-extracts/99d97e82a282
# I chose this area with regards to the recent events, I am proud of how California is at the frontier to right what is wrong.
# Also, the idea of contributing to the community is pretty cool.

# %%
import xml.etree.cElementTree as ET
import pprint
import re
import codecs
import json

# %%
import xml.etree.ElementTree as ET  # Use cElementTree or lxml if too slow

OSM_FILE = "san-francisco_california.osm" 
SF = "sanfran.osm.json"

k = 10 

def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag

    Reference:
    http://stackoverflow.com/questions/3095434/inserting-newlines-in-xml-file-generated-via-xml-etree-elementtree-in-python
    """
    context = iter(ET.iterparse(osm_file, events=('start', 'end')))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


with open(SF, 'wb') as output:
    output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
    output.write('<osm>\n  ')

    # Write every kth top level element
    for i, element in enumerate(get_element(OSM_FILE)):
        if i % k == 0:
            output.write(ET.tostring(element, encoding='utf-8'))

    output.write('</osm>')

# %%
from collections import defaultdict

def count_tags(filename):
    
    counts = defaultdict(int)
    for line in ET.iterparse(filename):
        current = line[1].tag
        counts[current] += 1
    return counts


def test():

    tags = count_tags(SF)
    pprint.pprint(tags)

    

if __name__ == "__main__":
    test()
# Out:
# defaultdict(<type 'int'>, {'node': 150957, 'nd': 187438, 'member': 2069, 'tag': 46296, 'relation': 242, 'way': 15655, 'osm': 1})

# %%
lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

def key_type(element, keys):
    if element.tag == "tag":
        
        if lower.search(element.attrib['k']):
            keys['lower'] += 1
        elif lower_colon.search(element.attrib['k']):
            keys['lower_colon'] += 1 
        elif problemchars.search(element.attrib['k']):
            keys['problemchars'] += 1
        else:
            keys['other'] += 1
        
    return keys



def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys



def test_data():
    # You can use another testfile 'map.osm' to look at your solution
    # Note that the assertions will be incorrect then.
    keys = process_map(SF)
    pprint.pprint(keys)



if __name__ == "__main__":
    test_data()
# Out:
# {'lower': 30041, 'lower_colon': 15738, 'other': 505, 'problemchars': 12}

# %%
def count_street(filename):
    streets = {}
    for event, elem in ET.iterparse(filename, events=('start', 'end')):
        if event == 'end':
            key = elem.attrib.get('k')
            if key == 'addr:street':
                street = elem.attrib.get('v')
                if street not in streets:
                    streets[street] = 1
                else:
                    streets[street] += 1
    return streets


postcodes = count_street(OSM_FILE)
sorted_by_occurrence = [(k, v) for (v, k) in sorted([(value, key) for (key, value) in postcodes.items()], reverse=True)]

print 'street values and occurrence in San-Francisco_california.osm:\n'
pprint.pprint(sorted_by_occurrence)
# Out:
# street values and occurrence in San-Francisco_california.osm:
#
# [('Irving Street', 593),
#  ('9th Avenue', 542),
#  ('14th Avenue', 432),
#  ('Page Street', 408),
#  ('10th Avenue', 395),
#  ('12th Avenue', 392),
#  ('Funston Avenue', 386),
#  ('11th Avenue', 369),
#  ('Taraval Street', 341),
#  ('8th Avenue', 340),
#  ('Church Street', 338),
#  ('Sanchez Street', 314),
#  ('Divisadero Street', 306),
#  ('Dolores Street', 288),
#  ('24th Street', 273),
#  ('Lincoln Way', 253),
#  ('Carl Street', 243),
#  ('Market Street', 222),
#  ('Judah Street', 216),
#  ('7th Avenue', 216),
#  ('Mission Street', 205),
#  ('Pacheco Street', 204),
#  ('Frederick Street', 192),
#  ('Vallejo Street', 190),
#  ('6th Avenue', 182),
#  ('Castro Street', 176),
#  ('Polk Street', 171),
#  ('23rd Street', 171),
#  ('Noriega Street', 170),
#  ('Stanyan Street', 169),
#  ('Folsom Street', 164),
#  ('Green Street', 160),
#  ('25th Street', 159),
#  ('Waller Street', 156),
#  ('Geary Boulevard', 156),
#  ('Oak Street', 155),
#  ('Valencia Street', 150),
#  ('5th Avenue', 150),
#  ('West Portal Avenue', 144),
#  ('Wawona Street', 143),
#  ('26th Street', 143),
#  ('17th Street', 141),
#  ('Haight Street', 137),
#  ('Kirkham Street', 135),
#  ('Guerrero Street', 132),
#  ('Pacific Avenue', 128),
#  ('Balboa Street', 128),
#  ('Magellan Avenue', 126),
#  ('Cesar Chavez Street', 124),
#  ('Van Ness Avenue', 123),
#  ('Parnassus Avenue', 120),
#  ('Lawton Street', 118),
#  ('Ortega Street', 117),
#  ('Quintara Street', 116),
#  ('Montgomery Street', 113),
#  ('Howard Street', 111),
#  ('Castenada Avenue', 109),
#  ('14th Street', 103),
#  ('Mason Street', 102),
#  ('4th Avenue', 102),
#  ('Fair Oaks Street', 101),
#  ('27th Street', 100),
#  ('Moraga Street', 99),
#  ('22nd Street', 99),
#  ('Hugo Street', 97),
#  ('28th Street', 97),
#  ('Willard Street', 96),
#  ('Stockton Street', 94),
#  ('Chestnut Street', 94),
#  ('19th Avenue', 94),
#  ('Powell Street', 93),
#  ('29th Street', 93),
#  ('3rd Avenue', 90),
#  ('Clipper Street', 87),
#  ('Jersey Street', 86),
#  ('Duncan Street', 86),
#  ('Cole Street', 86),
#  ('Valley Street', 84),
#  ('30th Street', 83),
#  ('California Street', 80),
#  ('15th Street', 79),
#  ('15th Avenue', 79),
#  ('Sutter Street', 78),
#  ('Union Street', 76),
#  ('Jackson Street', 74),
#  ('Geary Street', 74),
#  ('2nd Street', 74),
#  ('Day Street', 73),
#  ('Woodland Avenue', 72),
#  ('Ocean Avenue', 72),
#  ('Warren Drive', 69),
#  ('Ulloa Street', 69),
#  ('Kearny Street', 68),
#  ('Grant Avenue', 67),
#  ('Bush Street', 67),
#  ('3rd Street', 67),
#  ('Columbus Avenue', 66),
#  ('9th Street', 66),
#  ('16th Street', 66),
#  ('Henry Street', 65),
#  ('Forest Side Avenue', 64),
#  ('16th Avenue', 60),
#  ('Post Street', 58),
#  ('Larkin Street', 58),
#  ('Chattanooga Street', 56),
#  ('San Jose Avenue', 55),
#  ('Madrone Avenue', 55),
#  ('Fillmore Street', 55),
#  ('Dorantes Avenue', 55),
#  ('McAllister Street', 54),
#  ('Broadway Street', 53),
#  ('Broadway', 53),
#  ('Edgewood Avenue', 52),
#  ('Shrader Street', 51),
#  ('Natoma Street', 51),
#  ('Cragmont Avenue', 51),
#  ('2nd Avenue', 51),
#  ('Lombard Street', 50),
#  ('Langton Street', 50),
#  ('Greenwich Street', 48),
#  ('Vicente Street', 47),
#  ('Santiago Street', 47),
#  ('Noe Street', 47),
#  ('Franklin Street', 46),
#  ('Harrison Street', 45),
#  ('8th Street', 45),
#  ('Fulton Street', 43),
#  ('40th Avenue', 43),
#  ('18th Street', 42),
#  ('Mendosa Avenue', 40),
#  ('Hayes Street', 40),
#  ('San Marcos Avenue', 38),
#  ('Mars Street', 38),
#  ('Dewey Boulevard', 38),
#  ('Taylor Street', 37),
#  ('Rivera Street', 36),
#  ('Filbert Street', 36),
#  ('Ellis Street', 36),
#  ('Brannan Street', 35),
#  ('Arguello Boulevard', 35),
#  ('20th Avenue', 35),
#  ('Beaver Street', 34),
#  ('Vicksburg Street', 33),
#  ('Sansome Street', 33),
#  ('Randall Street', 33),
#  ('Spear Street', 32),
#  ('Bryant Street', 32),
#  ('17th Avenue', 32),
#  ('Pine Street', 31),
#  ('Golden Gate Avenue', 31),
#  ('4th Street', 31),
#  ('Sotelo Avenue', 30),
#  ('Portola Drive', 30),
#  ('Corbett Avenue', 30),
#  ('Lenox Way', 29),
#  ('Grove Street', 29),
#  ('Elizabeth Street', 29),
#  ('Clementina Street', 29),
#  ('Clement Street', 29),
#  ('7th Street', 29),
#  ('Steiner Street', 28),
#  ('Jones Street', 28),
#  ('Downey Street', 28),
#  ('18th Avenue', 28),
#  ('Fell Street', 27),
#  ('Eddy Street', 27),
#  ('Rausch Street', 26),
#  ('Santa Rita Avenue', 25),
#  ('Alton Avenue', 25),
#  ('36th Avenue', 25),
#  ('27th Avenue', 25),
#  ('20th Street', 25),
#  ('Washington Street', 24),
#  ("O'Farrell Street", 24),
#  ('Marcela Avenue', 23),
#  ('Locksley Avenue', 23),
#  ('Lopez Avenue', 22),
#  ('Ventura Avenue', 21),
#  ('New Montgomery Street', 21),
#  ('Dore Street', 21),
#  ('39th Avenue', 21),
#  ('34th Avenue', 21),
#  ('32nd Avenue', 21),
#  ('26th Avenue', 21),
#  ('21st Street', 21),
#  ('Sacramento Street', 20),
#  ('Prescott Court', 20),
#  ('John Street', 20),
#  ('Hyde Street', 20),
#  ('Cortland Avenue', 20),
#  ('Aloha Avenue', 20),
#  ('6th Street', 20),
#  ('31st Avenue', 20),
#  ('Broderick Street', 19),
#  ('37th Avenue', 19),
#  ('10th Street', 19),
#  ('Townsend Street', 18),
#  ('Stevenson Street', 18),
#  ('Clayton Street', 18),
#  ('35th Avenue', 18),
#  ('23rd Avenue', 18),
#  ('Lurline Street', 17),
#  ('Gough Street', 17),
#  ('Fort Mason', 17),
#  ('Ashbury Street', 17),
#  ('Sloat Boulevard', 16),
#  ('Bayshore Boulevard', 16),
#  ('Battery Street', 16),
#  ('38th Avenue', 16),
#  ('28th Avenue', 16),
#  ('24th Avenue', 16),
#  ('1st Street', 16),
#  ('The Embarcadero', 15),
#  ('Sumner Street', 15),
#  ('South Van Ness Avenue', 15),
#  ('Octavia Street', 15),
#  ('Montalvo Avenue', 15),
#  ('King Street', 15),
#  ('30th Avenue', 15),
#  ('21st Avenue', 15),
#  ('Whitney Street', 14),
#  ('Rodgers Street', 14),
#  ('Pierce Street', 14),
#  ('Minna Street', 14),
#  ('Masonic Avenue', 14),
#  ('Jefferson Street', 14),
#  ('Bonita Street', 14),
#  ('Berry Street', 14),
#  ('25th Avenue', 14),
#  ('White Street', 13),
#  ('Wayne Place', 13),
#  ('Rhode Island Street', 13),
#  ('Linares Avenue', 13),
#  ('Laguna Honda Boulevard', 13),
#  ('Duboce Avenue', 13),
#  ('Auburn Street', 13),
#  ('33rd Avenue', 13),
#  ('29th Avenue', 13),
#  ('22nd Avenue', 13),
#  ('Rockridge Drive', 12),
#  ('Bernard Street', 12),
#  ('Belvedere Street', 12),
#  ('11th Street', 12),
#  ('Scott Street', 11),
#  ('Monterey Boulevard', 11),
#  ('Hodges Alley', 11),
#  ('Hill Point Avenue', 11),
#  ('Webster Street', 10),
#  ('Steuart Street', 10),
#  ('Owens Street', 10),
#  ('Junipero Serra Boulevard', 10),
#  ('Diamond Street', 10),
#  ('Brown Street', 10),
#  ('5th Street', 10),
#  ('Rivoli Street', 9),
#  ('Mariposa Street', 9),
#  ('Lyon Street', 9),
#  ('Francisco Street', 9),
#  ('Clay Street', 9),
#  ('McCoppin Street', 8),
#  ('Leavenworth Street', 8),
#  ('Lakeshore Plaza', 8),
#  ('Laguna Street', 8),
#  ('Jasper Place', 8),
#  ('Holloway Avenue', 8),
#  ('Gateview Court', 8),
#  ('Florida Street', 8),
#  ('Eucalyptus Drive', 8),
#  ('Diamond Heights Boulevard', 8),
#  ('Devonshire Way', 8),
#  ('Claremont Boulevard', 8),
#  ('South Park', 7),
#  ('Sola Avenue', 7),
#  ('Sheldon Terrace', 7),
#  ('North Point Street', 7),
#  ('Main Street', 7),
#  ('Front Street', 7),
#  ('Fremont Street', 7),
#  ('De Haro Street', 7),
#  ('Central Avenue', 7),
#  ('Buena Vista Avenue West', 7),
#  ('Belmont Avenue', 7),
#  ('Beale Street', 7),
#  ('Bannam Place', 7),
#  ('Jessie Street', 6),
#  ('Hillway Avenue', 6),
#  ('Embarcadero Center', 6),
#  ('Chenery Street', 6),
#  ('California Avenue', 6),
#  ('Whiting Way', 5),
#  ('Vallejo', 5),
#  ('Turk Street', 5),
#  ('Trenton Street', 5),
#  ('Russ Street', 5),
#  ('Mason', 5),
#  ('Marina Boulevard', 5),
#  ('Kansas Street', 5),
#  ('Heron Street', 5),
#  ('Hattie Street', 5),
#  ('Gold Street', 5),
#  ('Fresno Street', 5),
#  ('Drumm Street', 5),
#  ('Davis Street', 5),
#  ('Beachmont Drive', 5),
#  ('Yorba Street', 4),
#  ('Yerba Buena Lane', 4),
#  ('Woodacre Drive', 4),
#  ('Waverly Place', 4),
#  ('Treat Avenue', 4),
#  ('States Street', 4),
#  ('San Leandro Way', 4),
#  ('Ross Alley', 4),
#  ('Ritch Street', 4),
#  ('Ringold Street', 4),
#  ('Rayburn Street', 4),
#  ('Radio Terrace', 4),
#  ('Potrero Avenue', 4),
#  ('Pier 39', 4),
#  ('Missouri St', 4),
#  ('Lomita Avenue', 4),
#  ('Lily Street', 4),
#  ('Liberty Street', 4),
#  ('Lagunitas Drive', 4),
#  ('Johnstone Drive', 4),
#  ('Gates Street', 4),
#  ('Division Street', 4),
#  ('Cortes Avenue', 4),
#  ('Cecilia Avenue', 4),
#  ('Buchanan Street', 4),
#  ('Bluxome Street', 4),
#  ('Beckett Street', 4),
#  ('Bayside Village Place', 4),
#  ('Bay Street', 4),
#  ('Baker Street', 4),
#  ('Winston Drive', 3),
#  ('Walter Street', 3),
#  ('Uranus Terrace', 3),
#  ('Upper Terrace', 3),
#  ('Salmon Street', 3),
#  ('Precita Avenue', 3),
#  ('Osgood Place', 3),
#  ('Oakdale Avenue', 3),
#  ('Mission Bay Boulevard North', 3),
#  ('Mint Plaza', 3),
#  ('Mesa Avenue', 3),
#  ('Loomis Street', 3),
#  ('Jamestown Avenue', 3),
#  ('Hillcrest Road', 3),
#  ('Hill Street', 3),
#  ('Fanning Way', 3),
#  ('Connecticut Street', 3),
#  ('Connecticut St', 3),
#  ('Carolina Street', 3),
#  ('Cargo Way', 3),
#  ('Boynton Court', 3),
#  ('Belden Place', 3),
#  ('Beach Street', 3),
#  ('Avenue of the Palms', 3),
#  ('August Alley', 3),
#  ('Alemany Boulevard', 3),
#  ('Alabama Street', 3),
#  ('Aerial Way', 3),
#  ('19th Street', 3),
#  ('Wisconsin Street', 2),
#  ('Willie Mays Plaza', 2),
#  ('Vermont Street', 2),
#  ('Trinity Place', 2),
#  ('Tompkins Avenue', 2),
#  ('Tiffany Avenue', 2),
#  ('Tennessee Street', 2),
#  ('South Park Avenue', 2),
#  ('San Bruno Avenue', 2),
#  ('Russian Hill Place', 2),
#  ('Romolo Place', 2),
#  ('Redfield Alley', 2),
#  ('Presidio Avenue', 2),
#  ('Pollard Place', 2),
#  ('Otis Street', 2),
#  ('Omar Way', 2),
#  ('Nottingham Place', 2),
#  ('New Montgomery St', 2),
#  ('Mission St', 2),
#  ('Minnesota Street', 2),
#  ('Merchant Street', 2),
#  ('Merced Avenue', 2),
#  ('Marin Street', 2),
#  ('Long Bridge Street', 2),
#  ('Lombard street', 2),
#  ('Kissling Street', 2),
#  ('Juri Street', 2),
#  ('Jennings Street', 2),
#  ('Ivy Street', 2),
#  ('Illinois Street', 2),
#  ('Hays Street', 2),
#  ('Hawthorne Street', 2),
#  ('Harriet Street', 2),
#  ('Grenard Terrace', 2),
#  ('Green St', 2),
#  ('Garden Way', 2),
#  ('Fowler Avenue', 2),
#  ('Font Boulevard', 2),
#  ('Florence Street', 2),
#  ('Fishermans Wharf', 2),
#  ('Ferry Building', 2),
#  ('Farnsworth Lane', 2),
#  ('Escolta Way', 2),
#  ('Deming Street', 2),
#  ('Delmar Street', 2),
#  ('Decatur Street', 2),
#  ('Cyril Magnin Street', 2),
#  ('Columbia Square Street', 2),
#  ('Claude Lane', 2),
#  ('Cervantes Boulevard', 2),
#  ('Cascade Walk', 2),
#  ('Capp Street', 2),
#  ('California', 2),
#  ('Belles Street', 2),
#  ('Bartlett Street', 2),
#  ('Anza Street', 2),
#  ('Ames Street', 2),
#  ('Alameda Street', 2),
#  ('13th Street', 2),
#  ('townsend street', 1),
#  ('Yosemite Avenue', 1),
#  ('York Street', 1),
#  ('York St', 1),
#  ('Yacht Road', 1),
#  ('Williams St', 1),
#  ('William Saroyan Place', 1),
#  ('Wilder Street', 1),
#  ('Wentworth Place', 1),
#  ('Wedemeyer', 1),
#  ('Webster Street #502', 1),
#  ('Wayland Street', 1),
#  ('Walter U Lum Place', 1),
#  ('Virginia Avenue', 1),
#  ('Vine Terrace', 1),
#  ('Via Ferlinghetti', 1),
#  ('Van Ness Ave', 1),
#  ('Van Ness', 1),
#  ('Van Dyke Avenue', 1),
#  ('Vallejo street', 1),
#  ('Vallejo Street Stairway', 1),
#  ('Valencia St', 1),
#  ('United Nations Plaza', 1),
#  ('Turk Boulevard', 1),
#  ('Tillman Place', 1),
#  ('Third Street', 1),
#  ('Terry Francois Street', 1),
#  ('Terry A Francois Boulevard', 1),
#  ('Terry A Francois Blvd', 1),
#  ('Tehama Street', 1),
#  ('Stark Street', 1),
#  ('Staples Avenue', 1),
#  ('South Gate Road', 1),
#  ('Sixth Street', 1),
#  ('Shotwell Street', 1),
#  ('Sheridan Avenue', 1),
#  ('Sharon Street', 1),
#  ('Shafter Avenue', 1),
#  ('Sergeant John V Young Lane', 1),
#  ('Second Street', 1),
#  ('Saramento Street', 1),
#  ('Sansome Street Suite 730', 1),
#  ('Sansome Street Ste 730', 1),
#  ('Sansome St #3500', 1),
#  ('San Francisco Bicycle Route 2', 1),
#  ('San Fernando Way', 1),
#  ('Saint Francis Place', 1),
#  ('SF 80 PM 4.5', 1),
#  ('Russia Avenue', 1),
#  ('Roosevelt Way', 1),
#  ('Post', 1),
#  ('Pollard', 1),
#  ('Plaza Street', 1),
#  ('Pier 50 B', 1),
#  ('Pier 50 A', 1),
#  ('Phelps Street', 1),
#  ('Phelan Avenue', 1),
#  ('Phelan Ave', 1),
#  ('Pershing Drive', 1),
#  ('Pennsylvania Avenue', 1),
#  ('Pennsylvania Ave', 1),
#  ('Paul Avenue', 1),
#  ('Panorama Drive', 1),
#  ('Pacific Avenue Mall', 1),
#  ('Oriole Way', 1),
#  ('One Letterman Drive', 1),
#  ('Octavia Boulevard', 1),
#  ('Norwich Street', 1),
#  ('Noe St', 1),
#  ('Niagara Avenue', 1),
#  ('New Montgomery', 1),
#  ('Nellie Street', 1),
#  ('Napoleon Street', 1),
#  ('Music Concourse Drive', 1),
#  ('Museum Way', 1),
#  ('Murray Street and Justin Drive', 1),
#  ('Multi Use Building', 1),
#  ('Moultrie Street', 1),
#  ('Morena Ave', 1),
#  ('Mississippi Street', 1),
#  ('Mission Rock Street', 1),
#  ('Mission Rock', 1),
#  ('Mint Street', 1),
#  ('Milton Street', 1),
#  ('Middlefield Drive', 1),
#  ('Mersey Street', 1),
#  ('Mendell St', 1),
#  ('Market Street Suite 3658', 1),
#  ('Market St.', 1),
#  ('Market St', 1),
#  ('Marine Drive', 1),
#  ('Marina Boulevard Building D', 1),
#  ('Marina Blvd', 1),
#  ('Maiden Lane', 1),
#  ('MIssion Street', 1),
#  ('Lyell Street', 1),
#  ('Lusk Street', 1),
#  ('Linden Street', 1),
#  ('Lincoln Boulevard', 1),
#  ('Lilac Alley', 1),
#  ('Lexington Street', 1),
#  ('Letterman Drive', 1),
#  ('Leidesdorff Street', 1),
#  ('Leavenworth St', 1),
#  ('Lansing Street', 1),
#  ('Lake Street', 1),
#  ('Koret Way', 1),
#  ('King', 1),
#  ('Kearny st', 1),
#  ('Kearny St', 1),
#  ('Jose Sarria Court', 1),
#  ('John F Kennedy Drive', 1),
#  ('Jerrold Avenue', 1),
#  ('Jerrold Ave', 1),
#  ('Isadora Duncan Lane', 1),
#  ('Industrial Street', 1),
#  ('Hyde', 1),
#  ('Hudson Street', 1),
#  ('Hooper Street', 1),
#  ('Holly Park Circle', 1),
#  ('Hoff Street', 1),
#  ('Hermann Street', 1),
#  ('Henry Adams Street', 1),
#  ('Hayes St', 1),
#  ('Harding Road', 1),
#  ('Hardie Place', 1),
#  ('Hampshire Street', 1),
#  ('Halleck St.', 1),
#  ('Hallam Street', 1),
#  ('Hagiwara Tea Garden Drive', 1),
#  ('Grant Ave', 1),
#  ('Gough', 1),
#  ('Gilbert Street', 1),
#  ('Geneva Avenue', 1),
#  ('Funston Road', 1),
#  ('Freelon Street', 1),
#  ('Francis Street', 1),
#  ('Fort Mason Center', 1),
#  ('Flood Avenue', 1),
#  ('Ferry Plaza', 1),
#  ('Federal Street', 1),
#  ('Eureka Street', 1),
#  ('Erie Street', 1),
#  ('Embarcadero', 1),
#  ('Ellsworth Street', 1),
#  ('Elim Street', 1),
#  ('Dr Carlton P Goodlett Place', 1),
#  ('Delancey Street', 1),
#  ('Delancey St', 1),
#  ('De Montfort Avenue', 1),
#  ('De Boom Street', 1),
#  ('Darien Way', 1),
#  ('Danvers Street', 1),
#  ('Daniel Burnham Court', 1),
#  ('Cosmo Place', 1),
#  ('Compton Road', 1),
#  ('Commercial Street', 1),
#  ('Clarence Place', 1),
#  ('Clara Street', 1),
#  ('Channel Street', 1),
#  ('Cesar Chavez St St', 1),
#  ('Castro St', 1),
#  ('Campton Place', 1),
#  ('California St.', 1),
#  ('Butte Place', 1),
#  ('Buena Vista Avenue East', 1),
#  ('Buckingham Way', 1),
#  ('Brosnan Street', 1),
#  ('Broadway Street; Mason Street', 1),
#  ('Brazil Avenue', 1),
#  ('Brannan St #151', 1),
#  ('Bosworth Street', 1),
#  ('Beulah Street', 1),
#  ('Belcher Street', 1),
#  ('Behr Avenue', 1),
#  ('Bay and Powell', 1),
#  ('Bartol Street', 1),
#  ('Bartlett Street #203', 1),
#  ('Bacon Street', 1),
#  ('Army Road', 1),
#  ('Arlington Street', 1),
#  ('Aptos Avenue', 1),
#  ('Amber Drive', 1),
#  ('Amador Street', 1),
#  ('9th St', 1),
#  ('434 Main Street', 1),
#  ('42nd Avenue', 1),
#  ('41st Avenue', 1),
#  ('3301 Lyon Street', 1),
#  ('303 Second Street', 1),
#  ('30 Rickard Street', 1),
#  ('2640 mason st', 1),
#  ('24th St', 1),
#  ('19th St', 1),
#  ('19th & Linda San Francisco', 1),
#  ('16th St #404', 1),
#  ('15th', 1),
#  ('14th St, San Francisco ', 1),
#  ('14th St', 1),
#  ('12th Street', 1)]

# %%
from collections import defaultdict
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)


expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons",'Terrace',"Plaza","Way","Center","Broadway","Post"]
# UPDATE THIS VARIABLE
mapping = { "St": "Street",
            "St.": "Street",
           'st':'Street',
            "Ave": "Avenue",
           'ave':"Avenue",
            "Rd.": "Road",
            "W.": "West",
            "N.": "North",
            "S.": "South",
            "E": "East",
           "Ln":'"Lane',
           'way':"Way"
          
          }


def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)


def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")


def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])

    return street_types

def update_name(name, mapping):
    after = []
    # Split name string to test each part of the name;
    # Replacements may come anywhere in the name.
    for part in name.split(" "):
        # Check each part of the name against the keys in the correction dict
        if part in mapping.keys():
            # If exists in dict, overwrite that part of the name with the dict value for it.
            part = mapping[part]
        # Assemble each corrected piece of the name back together.
        after.append(part)
    # Return all pieces of the name as a string joined by a space.
    return " ".join(after)
    
    return name
def map_test():
    st_types = audit(SF)
    pprint.pprint(dict(st_types))

    for st_type, ways in st_types.items():
        for name in ways:
            better_name = update_name(name, mapping)
            print name, "=>", better_name
            

if __name__ == '__main__':
    map_test()
# Out:
# {'Embarcadero': set(['The Embarcadero']),
#  'Ness': set(['Van Ness']),
#  'St': set(['Green St', 'Missouri St']),
#  'Vallejo': set(['Vallejo']),
#  'West': set(['Buena Vista Avenue West']),
#  'st': set(['2640 mason st'])}
# Vallejo => Vallejo
# Buena Vista Avenue West => Buena Vista Avenue West
# Van Ness => Van Ness
# The Embarcadero => The Embarcadero
# Green St => Green Street
# Missouri St => Missouri Street
# 2640 mason st => 2640 mason Street

# %%
def count_keys(filename):
    keys = {}
    for event, elem in ET.iterparse(filename, events=('start', 'end')):
        if event == 'end':
            key = elem.attrib.get('k')
            if key:
                if key not in keys:
                    keys[key] = 1
                else:
                    keys[key] += 1
    return keys

keys = count_keys(SF)
sorted_by_occurrence = [(k, v) for (v, k) in sorted([(value, key) for (key, value) in keys.items()], reverse=True)]

print 'Keys and occurrence in San-Francisco_california.osm:\n'
pprint.pprint(sorted_by_occurrence)
# Out:
# Keys and occurrence in San-Francisco_california.osm:
#
# [('building', 13500),
#  ('height', 4108),
#  ('addr:street', 2076),
#  ('name', 2013),
#  ('highway', 2012),
#  ('addr:housenumber', 2006),
#  ('addr:city', 1672),
#  ('addr:postcode', 1317),
#  ('addr:state', 1194),
#  ('tiger:county', 887),
#  ('addr:country', 880),
#  ('tiger:cfcc', 864),
#  ('tiger:name_type', 824),
#  ('tiger:name_base', 804),
#  ('amenity', 663),
#  ('tiger:zip_left', 648),
#  ('source', 572),
#  ('tiger:zip_right', 571),
#  ('oneway', 445),
#  ('natural', 362),
#  ('lanes', 352),
#  ('taxon', 296),
#  ('species:en', 281),
#  ('leisure', 256),
#  ('type', 251),
#  ('maxspeed', 237),
#  ('shop', 234),
#  ('operator', 207),
#  ('lcn_ref', 205),
#  ('tiger:reviewed', 180),
#  ('website', 177),
#  ('railway', 177),
#  ('leaf_cycle', 168),
#  ('sidewalk', 147),
#  ('tiger:tlid', 145),
#  ('tiger:source', 145),
#  ('tiger:separated', 143),
#  ('leaf_type', 143),
#  ('ref', 135),
#  ('phone', 129),
#  ('surface', 126),
#  ('cuisine', 116),
#  ('trolley_wire', 115),
#  ('building:levels', 115),
#  ('service', 110),
#  ('foot', 109),
#  ('restriction', 107),
#  ('crossing', 101),
#  ('landuse', 97),
#  ('cycleway', 93),
#  ('cycleway:right', 91),
#  ('created_by', 91),
#  ('bicycle', 91),
#  ('ele', 88),
#  ('gnis:feature_id', 82),
#  ('shelter', 74),
#  ('tourism', 71),
#  ('route_ref', 71),
#  ('OBJNAME', 71),
#  ('ticker', 67),
#  ('lanes:backward', 67),
#  ('lanes:forward', 66),
#  ('wheelchair', 62),
#  ('access', 62),
#  ('gnis:state_id', 61),
#  ('gnis:created', 61),
#  ('gnis:county_id', 61),
#  ('landcover', 60),
#  ('opening_hours', 59),
#  ('barrier', 59),
#  ('man_made', 55),
#  ('footway', 55),
#  ('turn:lanes', 53),
#  ('note', 53),
#  ('layer', 53),
#  ('area', 53),
#  ('tiger:name_base_1', 48),
#  ('capacity', 43),
#  ('BLDGID', 42),
#  ('AREA_M2', 39),
#  ('bridge', 35),
#  ('building:material', 32),
#  ('sport', 31),
#  ('route', 31),
#  ('tiger:upload_uuid', 29),
#  ('religion', 29),
#  ('bulb', 29),
#  ('turn_restrictions', 28),
#  ('office', 28),
#  ('network', 28),
#  ('hgv', 28),
#  ('seamark:type', 27),
#  ('alt_name', 25),
#  ('turn:lanes:forward', 24),
#  ('turn:lanes:backward', 24),
#  ('fee', 23),
#  ('source:hgv:state_network', 22),
#  ('hgv:state_network', 22),
#  ('tiger:name_type_1', 21),
#  ('gauge', 21),
#  ('tiger:zip_left_1', 20),
#  ('entrance', 20),
#  ('denomination', 20),
#  ('wikipedia', 19),
#  ('to', 19),
#  ('from', 19),
#  ('level', 18),
#  ('electrified', 18),
#  ('addr:housename', 18),
#  ('source:pkey', 17),
#  ('parking', 16),
#  ('gnis:county_name', 16),
#  ('atm', 16),
#  ('NHS', 16),
#  ('description', 15),
#  ('old_ref', 14),
#  ('emergency', 14),
#  ('traffic_signals:sound', 13),
#  ('restriction:conditional', 13),
#  ('quantity', 13),
#  ('name:zh', 13),
#  ('name:en', 13),
#  ('backrest', 13),
#  ('outside', 12),
#  ('common', 12),
#  ('Trunk_Diam', 12),
#  ('Subclass', 12),
#  ('survey:date', 11),
#  ('gnis:reviewed', 11),
#  ('gnis:import_uuid', 11),
#  ('craft', 11),
#  ('FIXME', 11),
#  ('outdoor_seating', 10),
#  ('name_1', 10),
#  ('maxweight', 10),
#  ('lit', 10),
#  ('email', 10),
#  ('traffic_calming', 9),
#  ('takeaway', 9),
#  ('sfgov:OBJNAME', 9),
#  ('payment:bitcoin', 9),
#  ('internet_access', 9),
#  ('tunnel', 8),
#  ('smoking', 8),
#  ('railway:traffic_mode', 8),
#  ('public_transport', 8),
#  ('placement:backward', 8),
#  ('colour', 8),
#  ('voltage', 7),
#  ('usage', 7),
#  ('old_name', 7),
#  ('motor_vehicle', 7),
#  ('hour_on', 7),
#  ('hour_off', 7),
#  ('gnis:edited', 7),
#  ('frequency', 7),
#  ('except', 7),
#  ('covered', 7),
#  ('brand', 7),
#  ('addr:interpolation', 7),
#  ('wikidata', 6),
#  ('tiger:zip_right_1', 6),
#  ('short_name', 6),
#  ('power', 6),
#  ('junction', 6),
#  ('day_on', 6),
#  ('day_off', 6),
#  ('cycleway:left', 6),
#  ('building:part', 6),
#  ('addr.source:housenumber', 6),
#  ('width', 5),
#  ('waterway', 5),
#  ('url', 5),
#  ('toilets', 5),
#  ('station_name', 5),
#  ('seamark:status', 5),
#  ('route_master', 5),
#  ('place', 5),
#  ('noexit', 5),
#  ('noaa:taghash', 5),
#  ('noaa:lnam', 5),
#  ('noaa:geohash', 5),
#  ('nextbus:agency', 5),
#  ('material', 5),
#  ('information', 5),
#  ('history', 5),
#  ('drive_through', 5),
#  ('designation', 5),
#  ('delivery', 5),
#  ('cycle_network', 5),
#  ('construction', 5),
#  ('wifi', 4),
#  ('traffic_signals', 4),
#  ('tiger:name_direction_prefix', 4),
#  ('tactile_paving', 4),
#  ('subway', 4),
#  ('payment:litecoin', 4),
#  ('parking:condition:right:2:time_interval', 4),
#  ('parking:condition:right:2:reason', 4),
#  ('parking:condition:right:2', 4),
#  ('owner', 4),
#  ('nextbus:route', 4),
#  ('name:ko', 4),
#  ('microbrewery', 4),
#  ('incline', 4),
#  ('horse', 4),
#  ('fixme', 4),
#  ('fire_hydrant:type', 4),
#  ('direction', 4),
#  ('cable_car', 4),
#  ('bench', 4),
#  ('addr:unit', 4),
#  ('via', 3),
#  ('turn:lanes:both_ways', 3),
#  ('toll', 3),
#  ('tiger:zip_left_2', 3),
#  ('start_date', 3),
#  ('sfgov.org:OFFICE_TYP', 3),
#  ('sfgov.org:OBJECTID', 3),
#  ('seamark:name', 3),
#  ('seamark:fog_signal:category', 3),
#  ('roof:shape', 3),
#  ('roof:colour', 3),
#  ('ref:blklot', 3),
#  ('psv', 3),
#  ('passenger', 3),
#  ('parking:lane:both', 3),
#  ('parking:condition:left:2:time_interval', 3),
#  ('parking:condition:left:2:reason', 3),
#  ('parking:condition:left:2', 3),
#  ('operator:type', 3),
#  ('maxlength', 3),
#  ('location', 3),
#  ('local_ref', 3),
#  ('lanes:both_ways', 3),
#  ('is_in', 3),
#  ('import_uuid', 3),
#  ('historic', 3),
#  ('gosm:sig:8CBDE645', 3),
#  ('golf', 3),
#  ('gnis:id', 3),
#  ('gnis:ST_num', 3),
#  ('gnis:ST_alpha', 3),
#  ('gnis:County_num', 3),
#  ('gnis:County', 3),
#  ('gnis:Class', 3),
#  ('fax', 3),
#  ('disused', 3),
#  ('depository', 3),
#  ('cutting', 3),
#  ('collection_times', 3),
#  ('bus', 3),
#  ('architect', 3),
#  ('Id', 3),
#  ('wetap:status', 2),
#  ('water', 2),
#  ('traction', 2),
#  ('toilets:disposal', 2),
#  ('symbol', 2),
#  ('supervised', 2),
#  ('source:name', 2),
#  ('source:hgv:national_network', 2),
#  ('social_facility', 2),
#  ('seamark:light:sequence', 2),
#  ('seamark:light:period', 2),
#  ('seamark:light:height', 2),
#  ('seamark:light:exhibition', 2),
#  ('seamark:light:colour', 2),
#  ('seamark:light:character', 2),
#  ('seamark:fog_signal:sequence', 2),
#  ('seamark:fog_signal:period', 2),
#  ('seamark:fog_signal:group', 2),
#  ('seamark:fog_signal:generation', 2),
#  ('seamark:daymark:shape', 2),
#  ('seamark:daymark:construction', 2),
#  ('seamark:daymark:colour_pattern', 2),
#  ('seamark:daymark:colour', 2),
#  ('seamark:beacon_lateral:shape', 2),
#  ('seamark:beacon_lateral:colour', 2),
#  ('seamark:beacon_lateral:category', 2),
#  ('ramp', 2),
#  ('placement', 2),
#  ('parking:condition:both:time_interval', 2),
#  ('parking:condition:both:residents', 2),
#  ('parking:condition:both:maxstay', 2),
#  ('parking:condition:both', 2),
#  ('outside_atm', 2),
#  ('origin', 2),
#  ('note:address', 2),
#  ('name_2', 2),
#  ('name:ru', 2),
#  ('name:de', 2),
#  ('min_height', 2),
#  ('map', 2),
#  ('island', 2),
#  ('is_in:state', 2),
#  ('hgv:national_network', 2),
#  ('healthcare', 2),
#  ('grades', 2),
#  ('grade', 2),
#  ('finished_laundry', 2),
#  ('exit_to', 2),
#  ('dry_clean', 2),
#  ('drop_off_only', 2),
#  ('dispensing', 2),
#  ('destination', 2),
#  ('crossing_ref', 2),
#  ('control', 2),
#  ('contact:website', 2),
#  ('contact:email', 2),
#  ('coin_op', 2),
#  ('building:min_level', 2),
#  ('building:colour', 2),
#  ('artwork_type', 2),
#  ('alterations', 2),
#  ('z_order', 1),
#  ('wine', 1),
#  ('wheelchair:description', 1),
#  ('wetap:statusnote', 1),
#  ('wetap:photo', 1),
#  ('vestibule_depository', 1),
#  ('vestibule_atm', 1),
#  ('verified', 1),
#  ('vehicle', 1),
#  ('train', 1),
#  ('trail_visibility', 1),
#  ('tiger:zip_right_2', 1),
#  ('terminal', 1),
#  ('taxi', 1),
#  ('street', 1),
#  ('stop_id', 1),
#  ('step_count', 1),
#  ('sports', 1),
#  ('source:addr:housenumber', 1),
#  ('social_facility:for', 1),
#  ('sloped_curb', 1),
#  ('service:bicycle:rental', 1),
#  ('seamark:light:range', 1),
#  ('seamark:information', 1),
#  ('seamark:beacon_special_purpose:shape', 1),
#  ('seamark:beacon_special_purpose:colour', 1),
#  ('seamark:beacon_safe_water:shape', 1),
#  ('seamark:beacon_lateral:reflectivity', 1),
#  ('sanitary_dump_station:pump-out', 1),
#  ('samtrans_route_ref', 1),
#  ('roof:height', 1),
#  ('ref:BART', 1),
#  ('rank', 1),
#  ('ramp:wheelchair', 1),
#  ('public_transport:version', 1),
#  ('postal_code', 1),
#  ('population', 1),
#  ('playground', 1),
#  ('parking_space', 1),
#  ('parking:condition:right:time_interval', 1),
#  ('parking:condition:right:residents', 1),
#  ('parking:condition:right:maxstay', 1),
#  ('parking:condition:right', 1),
#  ('parking:condition:left', 1),
#  ('park_ride', 1),
#  ('parapet', 1),
#  ('overtaking', 1),
#  ('outside_atm_operator', 1),
#  ('outside_atm_capacity', 1),
#  ('outerspatial:id', 1),
#  ('operator:wikipedia', 1),
#  ('opening_hours:url', 1),
#  ('old_tourism', 1),
#  ('nudism', 1),
#  ('notes', 1),
#  ('note:lcn', 1),
#  ('note:lanes', 1),
#  ('noname', 1),
#  ('nist:state_fips', 1),
#  ('nist:fips_code', 1),
#  ('nextbus:stopid', 1),
#  ('name_alt', 1),
#  ('name:ta', 1),
#  ('name:pt', 1),
#  ('name:kn', 1),
#  ('name:ja', 1),
#  ('name:hi', 1),
#  ('name:fa', 1),
#  ('name:eu', 1),
#  ('name:es', 1),
#  ('name:ca', 1),
#  ('mown', 1),
#  ('maxheight', 1),
#  ('male', 1),
#  ('localwiki', 1),
#  ('link', 1),
#  ('lcn', 1),
#  ('lanes:bus', 1),
#  ('is_in:country_code', 1),
#  ('is_in:country', 1),
#  ('is_in:continent', 1),
#  ('internet_access:fee', 1),
#  ('inside_atm', 1),
#  ('inner', 1),
#  ('indoor', 1),
#  ('image', 1),
#  ('hoops', 1),
#  ('historic:name', 1),
#  ('highway:disused', 1),
#  ('healthcare:speciality', 1),
#  ('hazard', 1),
#  ('has_outside_atm', 1),
#  ('gnis:feature_type', 1),
#  ('ford', 1),
#  ('fire_hydrant:position', 1),
#  ('field_marking', 1),
#  ('fence_type', 1),
#  ('exit_to:left', 1),
#  ('ethnicity', 1),
#  ('emergency:note', 1),
#  ('elevation', 1),
#  ('dog', 1),
#  ('disused:shop', 1),
#  ('disused:railway', 1),
#  ('disused:amenity', 1),
#  ('designer', 1),
#  ('county:name', 1),
#  ('county:ansi', 1),
#  ('county:abbrev', 1),
#  ('cooperative', 1),
#  ('contact:phone', 1),
#  ('community:gender', 1),
#  ('community', 1),
#  ('change:lanes:forward', 1),
#  ('change:backward', 1),
#  ('census:population', 1),
#  ('capacity:disabled', 1),
#  ('bus:lanes:forward', 1),
#  ('building:levels:underground', 1),
#  ('brand:wikidata', 1),
#  ('boundary', 1),
#  ('bottle', 1),
#  ('board_type', 1),
#  ('bicycle_parking', 1),
#  ('bearing', 1),
#  ('baby_hatch', 1),
#  ('attribution', 1),
#  ('attraction', 1),
#  ('area:railway', 1),
#  ('animal_shelter', 1),
#  ('amenity:disused', 1),
#  ('admin_level', 1),
#  ('address', 1),
#  ('addr:place', 1),
#  ('addr:full', 1)]

# %%
def count_postcodes(filename):
    postcodes = {}
    for event, elem in ET.iterparse(filename, events=('start', 'end')):
        if event == 'end':
            key = elem.attrib.get('k')
            if key == 'addr:postcode':
                postcode = elem.attrib.get('v')
                if postcode not in postcodes:
                    postcodes[postcode] = 1
                else:
                    postcodes[postcode] += 1
    return postcodes

postcodes = count_postcodes(OSM_FILE)
sorted_by_occurrence = [(k, v) for (v, k) in sorted([(value, key) for (key, value) in postcodes.items()], reverse=True)]

print 'Postcode values and occurrence in San-francisco_california.osm:\n'
pprint.pprint(sorted_by_occurrence)

# %%
def update_postcode(postcode):
    if re.match(r'$\d{5}^', postcode):
        return postcode
    try:
        return re.findall(r'^(\d{5})-\d{4}$', postcode)[0]
    except:
        pass

# %%
import xml.etree.cElementTree as ET
import pprint
import re
import codecs
import json

OSM_FILE = "san-francisco_california.osm" 
SF = "sanfran.osm.json"

lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

CREATED = [ "version", "changeset", "timestamp", "user", "uid"]

def is_address(elem):
    if elem.attrib['k'][:5] == "addr:":
        return True
        
def shape_element(element):
    node = {}
    if element.tag == "node" or element.tag == "way" :

        address_info={}
        nd_info=[]
        node['type']=element.tag
        node['id']=element.attrib['id']
        if 'visible' in element.attrib.keys():
            node['visible']=element.attrib['visible']
        if 'lat' in element.attrib.keys():
            node['pos']=[float(element.attrib['lat']), float(element.attrib['lon'])]
        node['created']={'version':element.attrib['version'],
                        'changeset':element.attrib['changeset'],
                        'timestamp':element.attrib['timestamp'],
                        'user':element.attrib['user'],
                        'uid':element.attrib['uid']}
        for tag in element.iter('tag'):
            p = problemchars.search(tag.attrib['k'])
            if tag.attrib['k']=='addr:street':
                update_name(tag.attrib['v'],mapping)
            if tag.attrib['k']=='addr:postcode':
                update_postcode(tag.attrib['v'])
            if p:
                continue
            elif is_address(tag):
                if ':' in tag.attrib['k'][5:]:
                    continue
                else:
                    address_info[tag.attrib['k'][5:]]=tag.attrib['v']
            else:
                node[tag.attrib['k']] = tag.attrib['v']
        if address_info != {}:
            node['address'] = address_info
        for tag2 in element.iter('nd'):
            nd_info.append(tag2.attrib['ref'])
        
        if nd_info != []:
            node['node_refs'] = nd_info
        return node
    else:
        return None


def process_map(file_in, pretty = False):

    file_out = "{0}.json".format(file_in)
    data = []
    with codecs.open(file_out, "w") as fo:
        for _, element in ET.iterparse(file_in):
            el = shape_element(element)
            if el:
                data.append(el)
                if pretty:
                    fo.write(json.dumps(el, indent=2)+"\n")
                else:
                    fo.write(json.dumps(el) + "\n")
    return data

def test():
    data = process_map(SF, True)
    pprint.pprint(data)
    
    

if __name__ == "__main__":
    test()
# Out:
# [{'census:population': '2010',
#   'created': {'changeset': '45401467',
#               'timestamp': '2017-01-23T14:46:00Z',
#               'uid': '25975',
#               'user': 'AmZaf',
#               'version': '41'},
#   'id': '26819236',
#   'is_in:continent': 'North America',
#   'is_in:country': 'United States',
#   'is_in:country_code': 'US',
#   'name': 'San Francisco',
#   'name:de': 'San Francisco',
#   'name:eu': 'San Francisco',
#   'name:fa': u'\u0633\u0627\u0646 \u0641\u0631\u0627\u0646\u0633\u06cc\u0633\u06a9\u0648',
#   'name:hi': u'\u0938\u0948\u0928 \u092b\u094d\u0930\u093e\u0902\u0938\u093f\u0938\u094d\u0915\u094b',
#   'name:ja': u'\u30b5\u30f3\u30d5\u30e9\u30f3\u30b7\u30b9\u30b3',
#   'name:kn': u'\u0cb8\u0cbe\u0ca8\u0ccd \u0cab\u0ccd\u0cb0\u0cbe\u0ca8\u0ccd\u0cb8\u0cbf\u0cb8\u0ccd\u0c95\u0cca',
#   'name:ko': u'\uc0cc\ud504\ub780\uc2dc\uc2a4\ucf54',
#   'name:pt': u'S\xe3o Francisco',
#   'name:ru': u'\u0421\u0430\u043d-\u0424\u0440\u0430\u043d\u0446\u0438\u0441\u043a\u043e',
#   'name:ta': u'\u0bb8\u0bbe\u0ba9\u0bcd \u0baa\u0bcd\xb2\u0bb0\u0bbe\u0ba9\u0bcd\u0bb8\u0bbf\u0bb8\u0bcd\u0b95\u0bca',
#   'name:zh': u'\u65e7\u91d1\u5c71',
#   'place': 'city',
#   'population': '864816',
#   'pos': [37.7792808, -122.4192363],
#   'rank': '10',
#   'short_name': 'SF',
#   'type': 'node',
#   'wikipedia': 'en:San Francisco',
#   'z_order': '2'},
#  {'created': {'changeset': '7186612',
#               'timestamp': '2011-02-04T20:40:16Z',
#               'uid': '4902',
#               'user': 'mbuege',
#               'version': '5'},
#   'id': '30677582',
#   'pos': [37.7784646, -122.3907111],
#   'type': 'node'},
#  {'created': {'changeset': '37561335',
#               'timestamp': '2016-03-02T08:42:18Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '11'},
#   'id': '30677713',
#   'pos': [37.765971, -122.4569404],
#   'type': 'node'},
#  {'created': {'changeset': '42369141',
#               'timestamp': '2016-09-23T09:49:01Z',
#               'uid': '933797',
#               'user': 'oba510',
#               'version': '8'},
#   'id': '31792960',
#   'pos': [37.8065725, -122.4528278],
#   'type': 'node'},
#  {'created': {'changeset': '12291412',
#               'timestamp': '2012-07-18T18:01:50Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '6'},
#   'id': '31796441',
#   'pos': [37.8072813, -122.4691139],
#   'type': 'node'},
#  {'created': {'changeset': '12291161',
#               'timestamp': '2012-07-18T17:50:55Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '5'},
#   'id': '31799178',
#   'pos': [37.80916, -122.4215511],
#   'type': 'node'},
#  {'created': {'changeset': '12290799',
#               'timestamp': '2012-07-18T17:36:33Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '4'},
#   'id': '31806013',
#   'pos': [37.8187038, -122.364363],
#   'type': 'node'},
#  {'created': {'changeset': '12291161',
#               'timestamp': '2012-07-18T17:50:57Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '8'},
#   'id': '31810743',
#   'pos': [37.8104907, -122.4259366],
#   'type': 'node'},
#  {'created': {'changeset': '12291161',
#               'timestamp': '2012-07-18T17:50:55Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '5'},
#   'id': '31815755',
#   'pos': [37.8091825, -122.4213816],
#   'type': 'node'},
#  {'created': {'changeset': '19241117',
#               'timestamp': '2013-12-02T21:00:22Z',
#               'uid': '27454',
#               'user': 'Popolon',
#               'version': '7'},
#   'id': '31819309',
#   'pos': [37.7286813, -122.3622569],
#   'type': 'node'},
#  {'created': {'changeset': '34010972',
#               'timestamp': '2015-09-14T00:09:12Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '8'},
#   'id': '31820688',
#   'pos': [37.8090704, -122.472962],
#   'type': 'node'},
#  {'created': {'changeset': '12291161',
#               'timestamp': '2012-07-18T17:50:58Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '6'},
#   'id': '31822031',
#   'pos': [37.811456, -122.4188098],
#   'type': 'node'},
#  {'created': {'changeset': '19241117',
#               'timestamp': '2013-12-02T21:08:10Z',
#               'uid': '27454',
#               'user': 'Popolon',
#               'version': '5'},
#   'id': '31824490',
#   'pos': [37.731639, -122.3656832],
#   'type': 'node'},
#  {'created': {'changeset': '12292969',
#               'timestamp': '2012-07-18T18:38:18Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '6'},
#   'id': '31825661',
#   'pos': [37.7384775, -122.3760739],
#   'type': 'node'},
#  {'created': {'changeset': '12292969',
#               'timestamp': '2012-07-18T18:38:21Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '6'},
#   'id': '31827017',
#   'pos': [37.7485248, -122.3922872],
#   'type': 'node'},
#  {'created': {'changeset': '12290799',
#               'timestamp': '2012-07-18T17:36:29Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '3'},
#   'id': '31828173',
#   'pos': [37.8091054, -122.3706984],
#   'type': 'node'},
#  {'created': {'changeset': '12290799',
#               'timestamp': '2012-07-18T17:36:31Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '4'},
#   'id': '31829267',
#   'pos': [37.8136945, -122.359316],
#   'type': 'node'},
#  {'created': {'changeset': '12291887',
#               'timestamp': '2012-07-18T18:16:20Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '4'},
#   'id': '31830205',
#   'pos': [37.7371861, -122.3749234],
#   'type': 'node'},
#  {'created': {'changeset': '12291161',
#               'timestamp': '2012-07-18T17:50:55Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '7'},
#   'id': '31831014',
#   'pos': [37.8091292, -122.4306546],
#   'type': 'node'},
#  {'created': {'changeset': '20091843',
#               'timestamp': '2014-01-19T19:50:27Z',
#               'uid': '1893220',
#               'user': 'luckiegurl37',
#               'version': '5'},
#   'id': '31831817',
#   'pos': [37.7651221, -122.386396],
#   'type': 'node'},
#  {'created': {'changeset': '12292969',
#               'timestamp': '2012-07-18T18:38:18Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '5'},
#   'id': '31833049',
#   'pos': [37.7244298, -122.3863287],
#   'type': 'node'},
#  {'created': {'changeset': '42369141',
#               'timestamp': '2016-09-23T09:49:01Z',
#               'uid': '933797',
#               'user': 'oba510',
#               'version': '7'},
#   'id': '31833958',
#   'pos': [37.8069697, -122.4686449],
#   'type': 'node'},
#  {'created': {'changeset': '12291161',
#               'timestamp': '2012-07-18T17:50:56Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '5'},
#   'id': '31834661',
#   'pos': [37.8096663, -122.4220434],
#   'type': 'node'},
#  {'created': {'changeset': '12291887',
#               'timestamp': '2012-07-18T18:16:17Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '6'},
#   'id': '31835518',
#   'pos': [37.7257308, -122.3648984],
#   'type': 'node'},
#  {'created': {'changeset': '12291161',
#               'timestamp': '2012-07-18T17:50:48Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '5'},
#   'id': '31836169',
#   'pos': [37.7898012, -122.3852995],
#   'type': 'node'},
#  {'created': {'changeset': '12291887',
#               'timestamp': '2012-07-18T18:16:21Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '5'},
#   'id': '31836599',
#   'pos': [37.7459038, -122.3749188],
#   'type': 'node'},
#  {'created': {'changeset': '12291161',
#               'timestamp': '2012-07-18T17:50:55Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '6'},
#   'id': '31837680',
#   'pos': [37.8089893, -122.4317476],
#   'type': 'node'},
#  {'created': {'changeset': '37360192',
#               'timestamp': '2016-02-22T07:10:12Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '7'},
#   'id': '31838750',
#   'pos': [37.8090681, -122.4125135],
#   'type': 'node'},
#  {'created': {'changeset': '12291887',
#               'timestamp': '2012-07-18T18:16:20Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '4'},
#   'id': '31839137',
#   'pos': [37.7380957, -122.370752],
#   'type': 'node'},
#  {'created': {'changeset': '12291887',
#               'timestamp': '2012-07-18T18:16:15Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '6'},
#   'id': '31840648',
#   'pos': [37.718954, -122.3717309],
#   'type': 'node'},
#  {'created': {'changeset': '12291161',
#               'timestamp': '2012-07-18T17:50:51Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '6'},
#   'id': '31841101',
#   'pos': [37.8060243, -122.4028024],
#   'type': 'node'},
#  {'created': {'changeset': '12291161',
#               'timestamp': '2012-07-18T17:50:57Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '8'},
#   'id': '31841677',
#   'pos': [37.810961, -122.4192647],
#   'type': 'node'},
#  {'created': {'changeset': '19241117',
#               'timestamp': '2013-12-02T21:08:09Z',
#               'uid': '27454',
#               'user': 'Popolon',
#               'version': '5'},
#   'id': '31842982',
#   'pos': [37.7331392, -122.3658749],
#   'type': 'node'},
#  {'created': {'changeset': '12291412',
#               'timestamp': '2012-07-18T18:01:45Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '3'},
#   'id': '31843682',
#   'pos': [37.7892598, -122.4890355],
#   'type': 'node'},
#  {'created': {'changeset': '12290799',
#               'timestamp': '2012-07-18T17:36:31Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '3'},
#   'id': '31844511',
#   'pos': [37.8132, -122.3650621],
#   'type': 'node'},
#  {'created': {'changeset': '12291161',
#               'timestamp': '2012-07-18T17:50:50Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '5'},
#   'id': '31845820',
#   'pos': [37.8006846, -122.3984045],
#   'type': 'node'},
#  {'created': {'changeset': '12290799',
#               'timestamp': '2012-07-18T17:36:34Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '4'},
#   'id': '31846460',
#   'pos': [37.8188741, -122.3642825],
#   'type': 'node'},
#  {'created': {'changeset': '12291161',
#               'timestamp': '2012-07-18T17:50:57Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '5'},
#   'id': '31847627',
#   'pos': [37.8103919, -122.4172172],
#   'type': 'node'},
#  {'created': {'changeset': '20091680',
#               'timestamp': '2014-01-19T19:41:09Z',
#               'uid': '1893220',
#               'user': 'luckiegurl37',
#               'version': '5'},
#   'id': '31848667',
#   'pos': [37.76315, -122.3852681],
#   'type': 'node'},
#  {'created': {'changeset': '12291887',
#               'timestamp': '2012-07-18T18:16:20Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '4'},
#   'id': '31849352',
#   'pos': [37.7373477, -122.3707701],
#   'type': 'node'},
#  {'created': {'changeset': '12291412',
#               'timestamp': '2012-07-18T18:01:51Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '4'},
#   'id': '31850336',
#   'pos': [37.8082588, -122.4407159],
#   'type': 'node'},
#  {'created': {'changeset': '12291412',
#               'timestamp': '2012-07-18T18:01:44Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '4'},
#   'id': '31851742',
#   'pos': [37.7879884, -122.4978237],
#   'type': 'node'},
#  {'created': {'changeset': '12291161',
#               'timestamp': '2012-07-18T17:50:48Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '6'},
#   'id': '31853701',
#   'pos': [37.7903746, -122.3884323],
#   'type': 'node'},
#  {'created': {'changeset': '12291412',
#               'timestamp': '2012-07-18T18:01:44Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '4'},
#   'id': '31854894',
#   'pos': [37.787812, -122.4948111],
#   'type': 'node'},
#  {'created': {'changeset': '12291161',
#               'timestamp': '2012-07-18T17:50:54Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '5'},
#   'id': '31856199',
#   'pos': [37.8087775, -122.4105014],
#   'type': 'node'},
#  {'created': {'changeset': '12291161',
#               'timestamp': '2012-07-18T17:50:52Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '7'},
#   'id': '31857821',
#   'pos': [37.8078249, -122.4298406],
#   'type': 'node'},
#  {'created': {'changeset': '12291887',
#               'timestamp': '2012-07-18T18:16:17Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '6'},
#   'id': '31858232',
#   'pos': [37.728783, -122.3573796],
#   'type': 'node'},
#  {'created': {'changeset': '12292969',
#               'timestamp': '2012-07-18T18:38:18Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '5'},
#   'id': '31858853',
#   'pos': [37.7239002, -122.3768873],
#   'type': 'node'},
#  {'created': {'changeset': '12291161',
#               'timestamp': '2012-07-18T17:50:45Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '6'},
#   'id': '31859614',
#   'pos': [37.7819345, -122.3855436],
#   'type': 'node'},
#  {'created': {'changeset': '29206031',
#               'timestamp': '2015-03-02T19:03:32Z',
#               'uid': '2441939',
#               'user': 'thevirginian',
#               'version': '9'},
#   'id': '31860246',
#   'pos': [37.8055905, -122.4587591],
#   'type': 'node'},
#  {'created': {'changeset': '12291161',
#               'timestamp': '2012-07-18T17:50:57Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '6'},
#   'id': '31861181',
#   'pos': [37.8105542, -122.4111537],
#   'type': 'node'},
#  {'created': {'changeset': '12290799',
#               'timestamp': '2012-07-18T17:36:30Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '3'},
#   'id': '31862180',
#   'pos': [37.8123535, -122.3666591],
#   'type': 'node'},
#  {'created': {'changeset': '12291161',
#               'timestamp': '2012-07-18T17:50:56Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '8'},
#   'id': '31862898',
#   'pos': [37.8100185, -122.4068192],
#   'type': 'node'},
#  {'created': {'changeset': '19241117',
#               'timestamp': '2013-12-02T21:00:22Z',
#               'uid': '27454',
#               'user': 'Popolon',
#               'version': '6'},
#   'id': '31864367',
#   'pos': [37.7315368, -122.3617988],
#   'type': 'node'},
#  {'created': {'changeset': '12291161',
#               'timestamp': '2012-07-18T17:50:56Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '7'},
#   'id': '31865816',
#   'pos': [37.8099075, -122.4107281],
#   'type': 'node'},
#  {'created': {'changeset': '34010972',
#               'timestamp': '2015-09-14T00:09:12Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '6'},
#   'id': '31868151',
#   'pos': [37.8089267, -122.4721093],
#   'type': 'node'},
#  {'created': {'changeset': '12291161',
#               'timestamp': '2012-07-18T17:50:52Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '7'},
#   'id': '31869928',
#   'pos': [37.807258, -122.4314539],
#   'type': 'node'},
#  {'created': {'changeset': '12291161',
#               'timestamp': '2012-07-18T17:50:55Z',
#               'uid': '722137',
#               'user': 'OSMF Redaction Account',
#               'version': '4'},
#   'id': '31873980',
#   'pos': [37.808888, -122.4112962],
#   'type': 'node'},
#  {'created': {'changeset': '37967355',
#               'timestamp': '2016-03-21T02:40:26Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '6'},
#   'id': '32925099',
#   'pos': [37.722752, -122.4970673],
#   'type': 'node'},
#  {'created': {'changeset': '4907255',
#               'timestamp': '2010-06-05T09:20:26Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '20'},
#   'id': '32927590',
#   'pos': [37.7319686, -122.4288029],
#   'type': 'node'},
#  {'created': {'changeset': '11360720',
#               'timestamp': '2012-04-20T06:39:58Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '13'},
#   'id': '54890317',
#   'pos': [37.7744819, -122.3914271],
#   'type': 'node'},
#  {'created': {'changeset': '7370320',
#               'timestamp': '2011-02-23T08:34:05Z',
#               'uid': '116029',
#               'user': 'Gregory Arenius',
#               'version': '4'},
#   'id': '54906568',
#   'pos': [37.7700189, -122.4430704],
#   'type': 'node'},
#  {'created': {'changeset': '7370320',
#               'timestamp': '2011-02-23T08:33:59Z',
#               'uid': '116029',
#               'user': 'Gregory Arenius',
#               'version': '4'},
#   'id': '54906586',
#   'pos': [37.7679124, -122.4399774],
#   'type': 'node'},
#  {'address': {'street': 'Haight Street'},
#   'amenity': 'pub',
#   'created': {'changeset': '24232726',
#               'timestamp': '2014-07-19T03:41:48Z',
#               'uid': '25985',
#               'user': 'mattflaschen',
#               'version': '7'},
#   'id': '61672275',
#   'name': 'Noc Noc',
#   'pos': [37.771878, -122.4315768],
#   'short_name': 'NocNoc',
#   'type': 'node'},
#  {'amenity': 'pub',
#   'created': {'changeset': '4157389',
#               'timestamp': '2010-03-17T21:56:58Z',
#               'uid': '109925',
#               'user': 'WanMil',
#               'version': '3'},
#   'id': '61678786',
#   'name': 'Aub Zam Zam',
#   'pos': [37.7695485, -122.4492617],
#   'type': 'node'},
#  {'created': {'changeset': '3156706',
#               'timestamp': '2009-11-19T03:33:07Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '65279860',
#   'pos': [37.723583, -122.386139],
#   'type': 'node'},
#  {'created': {'changeset': '3156706',
#               'timestamp': '2009-11-19T03:33:08Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '65279914',
#   'pos': [37.727425, -122.382687],
#   'type': 'node'},
#  {'created': {'changeset': '3156706',
#               'timestamp': '2009-11-19T03:33:08Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '3'},
#   'id': '65279957',
#   'pos': [37.7343192, -122.3764909],
#   'type': 'node'},
#  {'created': {'changeset': '37656459',
#               'timestamp': '2016-03-07T00:41:29Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '4'},
#   'id': '65279992',
#   'pos': [37.7510017, -122.4690073],
#   'type': 'node'},
#  {'created': {'changeset': '37655993',
#               'timestamp': '2016-03-06T23:39:38Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '6'},
#   'id': '65280044',
#   'pos': [37.7489418, -122.4684993],
#   'type': 'node'},
#  {'created': {'changeset': '37655993',
#               'timestamp': '2016-03-06T23:39:38Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '6'},
#   'id': '65280099',
#   'pos': [37.7433923, -122.4681124],
#   'type': 'node'},
#  {'created': {'changeset': '3156706',
#               'timestamp': '2009-11-19T03:33:11Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '3'},
#   'id': '65280143',
#   'pos': [37.757891, -122.447303],
#   'type': 'node'},
#  {'created': {'changeset': '11274865',
#               'timestamp': '2012-04-12T11:20:12Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '5'},
#   'id': '65280326',
#   'pos': [37.7193559, -122.450852],
#   'type': 'node'},
#  {'created': {'changeset': '44514177',
#               'timestamp': '2016-12-19T11:49:22Z',
#               'uid': '3272286',
#               'user': 'manings',
#               'version': '5'},
#   'highway': 'traffic_signals',
#   'id': '65280377',
#   'pos': [37.7336837, -122.426389],
#   'type': 'node'},
#  {'created': {'changeset': '11359825',
#               'timestamp': '2012-04-20T02:19:04Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '5'},
#   'id': '65280423',
#   'pos': [37.7332979, -122.432618],
#   'type': 'node'},
#  {'created': {'changeset': '44513241',
#               'timestamp': '2016-12-19T11:00:57Z',
#               'uid': '3272286',
#               'user': 'manings',
#               'version': '12'},
#   'highway': 'traffic_signals',
#   'id': '65280473',
#   'pos': [37.7348747, -122.4399937],
#   'type': 'node'},
#  {'created': {'changeset': '12095476',
#               'timestamp': '2012-07-03T00:29:01Z',
#               'uid': '169004',
#               'user': 'oldtopos',
#               'version': '10'},
#   'exit_to': 'Monterey Boulevard',
#   'highway': 'motorway_junction',
#   'id': '65280506',
#   'pos': [37.7322539, -122.4321208],
#   'ref': '52',
#   'type': 'node'},
#  {'created': {'changeset': '16261778',
#               'timestamp': '2013-05-24T08:02:28Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '5'},
#   'id': '65280607',
#   'pos': [37.7361319, -122.4419128],
#   'type': 'node'},
#  {'created': {'changeset': '4489370',
#               'timestamp': '2010-04-21T18:37:48Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '5'},
#   'id': '65280776',
#   'pos': [37.7536775, -122.4423951],
#   'type': 'node'},
#  {'created': {'changeset': '4838660',
#               'timestamp': '2010-05-29T00:25:45Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '3'},
#   'id': '65280811',
#   'pos': [37.7528954, -122.4492324],
#   'type': 'node'},
#  {'created': {'changeset': '16261778',
#               'timestamp': '2013-05-24T08:21:14Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '4'},
#   'id': '65280857',
#   'pos': [37.7436504, -122.4524672],
#   'type': 'node'},
#  {'created': {'changeset': '11361726',
#               'timestamp': '2012-04-20T09:04:30Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '29'},
#   'highway': 'traffic_signals',
#   'id': '65281218',
#   'pos': [37.7718581, -122.423322],
#   'type': 'node'},
#  {'created': {'changeset': '37130950',
#               'timestamp': '2016-02-10T18:25:13Z',
#               'uid': '2226712',
#               'user': 'dannykath',
#               'version': '5'},
#   'id': '65281376',
#   'pos': [37.7510899, -122.4061123],
#   'type': 'node'},
#  {'created': {'changeset': '37130950',
#               'timestamp': '2016-02-10T18:25:13Z',
#               'uid': '2226712',
#               'user': 'dannykath',
#               'version': '6'},
#   'id': '65281580',
#   'pos': [37.7489612, -122.4065323],
#   'type': 'node'},
#  {'created': {'changeset': '5011590',
#               'timestamp': '2010-06-17T19:55:25Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '5'},
#   'id': '65281640',
#   'pos': [37.7500636, -122.4031404],
#   'type': 'node'},
#  {'created': {'changeset': '5011590',
#               'timestamp': '2010-06-17T19:44:29Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '7'},
#   'id': '65281743',
#   'pos': [37.7496733, -122.4039907],
#   'type': 'node'},
#  {'created': {'changeset': '5452345',
#               'timestamp': '2010-08-10T10:03:47Z',
#               'uid': '116029',
#               'user': 'Gregory Arenius',
#               'version': '4'},
#   'id': '65281826',
#   'pos': [37.7879024, -122.4164834],
#   'type': 'node'},
#  {'created': {'changeset': '5011590',
#               'timestamp': '2010-06-17T19:42:19Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '8'},
#   'id': '65281874',
#   'pos': [37.7496861, -122.4040886],
#   'type': 'node'},
#  {'created': {'changeset': '39679418',
#               'timestamp': '2016-05-31T03:31:06Z',
#               'uid': '1282393',
#               'user': 'Reno Editor',
#               'version': '13'},
#   'exit_to:left': '5th Street',
#   'highway': 'motorway_junction',
#   'id': '65281944',
#   'pos': [37.7823664, -122.3963904],
#   'ref': '2A',
#   'source': 'http://www.dot.ca.gov/hq/traffops/signtech/calnexus/pdf/80.pdf',
#   'type': 'node'},
#  {'created': {'changeset': '12083111',
#               'timestamp': '2012-07-02T04:32:05Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '4'},
#   'id': '65282120',
#   'pos': [37.7334368, -122.4903906],
#   'type': 'node'},
#  {'created': {'changeset': '5011940',
#               'timestamp': '2010-06-17T20:11:10Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '7'},
#   'id': '65282190',
#   'pos': [37.7463123, -122.4042943],
#   'type': 'node'},
#  {'created': {'changeset': '33698026',
#               'timestamp': '2015-08-31T08:42:11Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '6'},
#   'id': '65282292',
#   'pos': [37.8001937, -122.4613853],
#   'type': 'node'},
#  {'created': {'changeset': '20683290',
#               'timestamp': '2014-02-20T21:09:59Z',
#               'uid': '436419',
#               'user': 'wvdp',
#               'version': '3'},
#   'id': '65282329',
#   'pos': [37.7984628, -122.461078],
#   'type': 'node'},
#  {'created': {'changeset': '4932734',
#               'timestamp': '2010-06-07T21:33:45Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '5'},
#   'id': '65282363',
#   'pos': [37.7377459, -122.4072606],
#   'type': 'node'},
#  {'created': {'changeset': '3156706',
#               'timestamp': '2009-11-19T03:33:34Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '5'},
#   'id': '65282392',
#   'pos': [37.8063062, -122.474677],
#   'type': 'node'},
#  {'created': {'changeset': '34010312',
#               'timestamp': '2015-09-13T22:59:07Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '4'},
#   'id': '65282422',
#   'pos': [37.8076026, -122.473999],
#   'type': 'node'},
#  {'created': {'changeset': '34010312',
#               'timestamp': '2015-09-13T22:59:07Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '4'},
#   'id': '65282452',
#   'pos': [37.8071075, -122.4734413],
#   'type': 'node'},
#  {'created': {'changeset': '7970327',
#               'timestamp': '2011-04-26T01:26:56Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '4'},
#   'id': '65282490',
#   'pos': [37.7738037, -122.4061625],
#   'type': 'node'},
#  {'created': {'changeset': '7970327',
#               'timestamp': '2011-04-26T01:26:56Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '5'},
#   'id': '65282542',
#   'pos': [37.7744068, -122.4063576],
#   'type': 'node'},
#  {'created': {'changeset': '4943063',
#               'timestamp': '2010-06-09T08:09:14Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '3'},
#   'id': '65282579',
#   'pos': [37.7220005, -122.4008812],
#   'type': 'node'},
#  {'created': {'changeset': '7970327',
#               'timestamp': '2011-04-26T01:26:57Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '4'},
#   'id': '65282781',
#   'pos': [37.7804665, -122.3996494],
#   'type': 'node'},
#  {'created': {'changeset': '11318458',
#               'timestamp': '2012-04-16T06:35:14Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '5'},
#   'id': '65282900',
#   'pos': [37.7309764, -122.4354221],
#   'type': 'node'},
#  {'created': {'changeset': '11318458',
#               'timestamp': '2012-04-16T06:35:14Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '5'},
#   'id': '65282985',
#   'pos': [37.7308223, -122.4355507],
#   'type': 'node'},
#  {'created': {'changeset': '11318458',
#               'timestamp': '2012-04-16T06:35:14Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '6'},
#   'id': '65283067',
#   'pos': [37.7320702, -122.4346683],
#   'type': 'node'},
#  {'created': {'changeset': '4693131',
#               'timestamp': '2010-05-14T08:00:54Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '4'},
#   'id': '65283151',
#   'pos': [37.807939, -122.4425817],
#   'type': 'node'},
#  {'created': {'changeset': '37383853',
#               'timestamp': '2016-02-23T09:30:19Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '5'},
#   'id': '65283183',
#   'pos': [37.7801136, -122.49765],
#   'type': 'node'},
#  {'created': {'changeset': '8637670',
#               'timestamp': '2011-07-05T10:25:23Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '5'},
#   'id': '65283236',
#   'pos': [37.7203957, -122.4837476],
#   'type': 'node'},
#  {'created': {'changeset': '4933047',
#               'timestamp': '2010-06-07T22:06:41Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '6'},
#   'id': '65283283',
#   'pos': [37.7539226, -122.391531],
#   'type': 'node'},
#  {'created': {'changeset': '37110991',
#               'timestamp': '2016-02-09T20:45:23Z',
#               'uid': '2226712',
#               'user': 'dannykath',
#               'version': '6'},
#   'id': '65283366',
#   'pos': [37.751285, -122.392499],
#   'type': 'node'},
#  {'created': {'changeset': '37404343',
#               'timestamp': '2016-02-24T04:53:56Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '6'},
#   'highway': 'crossing',
#   'id': '65283419',
#   'pos': [37.7907691, -122.4588575],
#   'type': 'node'},
#  {'created': {'changeset': '11740644',
#               'timestamp': '2012-05-29T18:01:33Z',
#               'uid': '116029',
#               'user': 'Gregory Arenius',
#               'version': '3'},
#   'id': '65283463',
#   'pos': [37.7935466, -122.450228],
#   'type': 'node'},
#  {'created': {'changeset': '4943185',
#               'timestamp': '2010-06-09T08:44:38Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '5'},
#   'id': '65283497',
#   'pos': [37.7533217, -122.3924731],
#   'type': 'node'},
#  {'created': {'changeset': '31336567',
#               'timestamp': '2015-05-21T08:04:14Z',
#               'uid': '33757',
#               'user': 'Minh Nguyen',
#               'version': '5'},
#   'id': '65283553',
#   'pos': [37.7696787, -122.4057206],
#   'type': 'node'},
#  {'created': {'changeset': '4943185',
#               'timestamp': '2010-06-09T08:35:50Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '4'},
#   'id': '65283643',
#   'pos': [37.7618061, -122.3928043],
#   'type': 'node'},
#  {'created': {'changeset': '12517079',
#               'timestamp': '2012-07-27T22:02:05Z',
#               'uid': '67236',
#               'user': 'jfire',
#               'version': '3'},
#   'id': '65283676',
#   'pos': [37.7677478, -122.4412125],
#   'type': 'node'},
#  {'created': {'changeset': '3156706',
#               'timestamp': '2009-11-19T03:33:46Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '65283700',
#   'pos': [37.766394, -122.441985],
#   'type': 'node'},
#  {'created': {'changeset': '4692759',
#               'timestamp': '2010-05-14T07:21:00Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '7'},
#   'id': '65283735',
#   'pos': [37.7709424, -122.4086307],
#   'type': 'node'},
#  {'created': {'changeset': '21087627',
#               'timestamp': '2014-03-13T19:03:53Z',
#               'uid': '1679807',
#               'user': 'Cato_d_Ae',
#               'version': '7'},
#   'id': '65283778',
#   'pos': [37.7693622, -122.4076107],
#   'type': 'node'},
#  {'created': {'changeset': '4692759',
#               'timestamp': '2010-05-14T07:11:52Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '7'},
#   'id': '65283829',
#   'pos': [37.7691858, -122.4061899],
#   'type': 'node'},
#  {'created': {'changeset': '16261471',
#               'timestamp': '2013-05-24T07:31:54Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '4'},
#   'id': '65283863',
#   'pos': [37.7432404, -122.4537686],
#   'type': 'node'},
#  {'created': {'changeset': '5011940',
#               'timestamp': '2010-06-17T20:10:15Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '4'},
#   'id': '65283923',
#   'pos': [37.7463388, -122.4040342],
#   'type': 'node'},
#  {'created': {'changeset': '4663476',
#               'timestamp': '2010-05-10T20:45:06Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '5'},
#   'id': '65284012',
#   'pos': [37.7510577, -122.4030712],
#   'type': 'node'},
#  {'created': {'changeset': '37164955',
#               'timestamp': '2016-02-12T10:32:27Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '9'},
#   'id': '65284093',
#   'pos': [37.8039161, -122.4699798],
#   'type': 'node'},
#  {'created': {'changeset': '4944013',
#               'timestamp': '2010-06-09T10:18:42Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '4'},
#   'id': '65284139',
#   'pos': [37.7186712, -122.3998454],
#   'type': 'node'},
#  {'created': {'changeset': '33698948',
#               'timestamp': '2015-08-31T09:25:59Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '4'},
#   'id': '65284255',
#   'pos': [37.8077421, -122.475403],
#   'type': 'node'},
#  {'created': {'changeset': '33698026',
#               'timestamp': '2015-08-31T08:42:11Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '7'},
#   'id': '65284288',
#   'pos': [37.8074703, -122.4743302],
#   'type': 'node'},
#  {'created': {'changeset': '33698026',
#               'timestamp': '2015-08-31T08:42:11Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '4'},
#   'id': '65284351',
#   'pos': [37.7974834, -122.465058],
#   'type': 'node'},
#  {'created': {'changeset': '33698026',
#               'timestamp': '2015-08-31T08:42:12Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '4'},
#   'id': '65284380',
#   'pos': [37.7993847, -122.4662955],
#   'type': 'node'},
#  {'created': {'changeset': '11318458',
#               'timestamp': '2012-04-16T06:35:13Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '4'},
#   'id': '65284424',
#   'pos': [37.7338512, -122.4313053],
#   'type': 'node'},
#  {'created': {'changeset': '43788374',
#               'timestamp': '2016-11-19T03:42:04Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '4'},
#   'id': '65284521',
#   'pos': [37.7854268, -122.3924603],
#   'type': 'node'},
#  {'created': {'changeset': '3156706',
#               'timestamp': '2009-11-19T03:33:57Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '65284558',
#   'pos': [37.760936, -122.385629],
#   'type': 'node'},
#  {'created': {'changeset': '11274865',
#               'timestamp': '2012-04-12T11:20:12Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '4'},
#   'id': '65284589',
#   'pos': [37.7259195, -122.4465105],
#   'type': 'node'},
#  {'created': {'changeset': '11274865',
#               'timestamp': '2012-04-12T10:55:54Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '5'},
#   'id': '65284617',
#   'pos': [37.7230691, -122.4488309],
#   'type': 'node'},
#  {'created': {'changeset': '4905965',
#               'timestamp': '2010-06-05T05:12:47Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '4'},
#   'id': '65284661',
#   'pos': [37.7249815, -122.446572],
#   'type': 'node'},
#  {'created': {'changeset': '5011590',
#               'timestamp': '2010-06-17T19:34:08Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '4'},
#   'id': '65284702',
#   'pos': [37.7488335, -122.4060613],
#   'type': 'node'},
#  {'created': {'changeset': '4933190',
#               'timestamp': '2010-06-07T22:25:36Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '7'},
#   'id': '65284899',
#   'pos': [37.7375803, -122.408205],
#   'type': 'node'},
#  {'created': {'changeset': '7970327',
#               'timestamp': '2011-04-26T01:26:57Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '9'},
#   'id': '65284945',
#   'pos': [37.7794233, -122.3989864],
#   'type': 'node'},
#  {'created': {'changeset': '40735893',
#               'timestamp': '2016-07-14T10:30:48Z',
#               'uid': '933797',
#               'user': 'oba510',
#               'version': '7'},
#   'crossing': 'uncontrolled',
#   'highway': 'crossing',
#   'id': '65285015',
#   'pos': [37.7628398, -122.495751],
#   'type': 'node'},
#  {'created': {'changeset': '2102778',
#               'timestamp': '2009-08-10T21:48:47Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '65285092',
#   'pos': [37.730643, -122.365351],
#   'type': 'node'},
#  {'created': {'changeset': '23048396',
#               'timestamp': '2014-06-20T16:59:28Z',
#               'uid': '1240849',
#               'user': 'ediyes',
#               'version': '3'},
#   'id': '65285127',
#   'pos': [37.7279864, -122.3581053],
#   'type': 'node'},
#  {'created': {'changeset': '5011590',
#               'timestamp': '2010-06-17T19:42:02Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '4'},
#   'id': '65285245',
#   'pos': [37.7494263, -122.4043729],
#   'type': 'node'},
#  {'created': {'changeset': '2102778',
#               'timestamp': '2009-08-10T21:48:49Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '5'},
#   'id': '65285355',
#   'pos': [37.8089247, -122.366807],
#   'type': 'node'},
#  {'created': {'changeset': '37303895',
#               'timestamp': '2016-02-19T09:00:46Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '5'},
#   'id': '65285432',
#   'pos': [37.7844452, -122.4297666],
#   'type': 'node'},
#  {'created': {'changeset': '4907465',
#               'timestamp': '2010-06-05T09:55:26Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '4'},
#   'id': '65285520',
#   'pos': [37.7317014, -122.4169075],
#   'type': 'node'},
#  {'created': {'changeset': '10559598',
#               'timestamp': '2012-02-01T15:23:58Z',
#               'uid': '236172',
#               'user': 'saikofish',
#               'version': '5'},
#   'id': '65285615',
#   'pos': [37.7781226, -122.3953181],
#   'type': 'node'},
#  {'created': {'changeset': '20683290',
#               'timestamp': '2014-02-20T21:10:00Z',
#               'uid': '436419',
#               'user': 'wvdp',
#               'version': '4'},
#   'id': '65285664',
#   'pos': [37.7992285, -122.4621656],
#   'type': 'node'},
#  {'created': {'changeset': '37660747',
#               'timestamp': '2016-03-07T08:32:55Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '5'},
#   'id': '65285705',
#   'pos': [37.7787978, -122.4515174],
#   'type': 'node'},
#  {'created': {'changeset': '33698583',
#               'timestamp': '2015-08-31T09:09:05Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '4'},
#   'id': '65285743',
#   'pos': [37.7968813, -122.4479805],
#   'type': 'node'},
#  {'created': {'changeset': '7970327',
#               'timestamp': '2011-04-26T01:26:58Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '5'},
#   'id': '65285843',
#   'pos': [37.7733785, -122.4068281],
#   'type': 'node'},
#  {'created': {'changeset': '4932734',
#               'timestamp': '2010-06-07T21:32:08Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '4'},
#   'id': '65285911',
#   'pos': [37.7354466, -122.4098235],
#   'type': 'node'},
#  {'created': {'changeset': '36957831',
#               'timestamp': '2016-02-02T14:04:54Z',
#               'uid': '2226712',
#               'user': 'dannykath',
#               'version': '6'},
#   'id': '65285992',
#   'pos': [37.7280072, -122.4025193],
#   'type': 'node'},
#  {'created': {'changeset': '37660747',
#               'timestamp': '2016-03-07T08:32:55Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '5'},
#   'id': '65286047',
#   'pos': [37.7798997, -122.4534645],
#   'type': 'node'},
#  {'created': {'changeset': '7970327',
#               'timestamp': '2011-04-26T01:26:59Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '4'},
#   'id': '65286128',
#   'pos': [37.7751142, -122.4065613],
#   'type': 'node'},
#  {'created': {'changeset': '2102778',
#               'timestamp': '2009-08-10T21:49:02Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '3'},
#   'id': '65286179',
#   'pos': [37.746924, -122.447579],
#   'type': 'node'},
#  {'created': {'changeset': '43788374',
#               'timestamp': '2016-11-19T03:42:05Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '12'},
#   'id': '65286238',
#   'pos': [37.78508, -122.3935024],
#   'type': 'node'},
#  {'created': {'changeset': '12517079',
#               'timestamp': '2012-07-27T22:02:04Z',
#               'uid': '67236',
#               'user': 'jfire',
#               'version': '3'},
#   'id': '65286340',
#   'pos': [37.767793, -122.441345],
#   'type': 'node'},
#  {'created': {'changeset': '12517079',
#               'timestamp': '2012-07-27T22:02:05Z',
#               'uid': '67236',
#               'user': 'jfire',
#               'version': '3'},
#   'id': '65286365',
#   'pos': [37.7676521, -122.4413933],
#   'type': 'node'},
#  {'created': {'changeset': '36336167',
#               'timestamp': '2016-01-03T11:46:46Z',
#               'uid': '933797',
#               'user': 'oba510',
#               'version': '4'},
#   'id': '65286396',
#   'pos': [37.7543679, -122.4050887],
#   'type': 'node'},
#  {'created': {'changeset': '4663164',
#               'timestamp': '2010-05-10T20:17:39Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '4'},
#   'id': '65286458',
#   'pos': [37.7633602, -122.4047145],
#   'type': 'node'},
#  {'created': {'changeset': '4943185',
#               'timestamp': '2010-06-09T08:36:26Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '4'},
#   'id': '65286500',
#   'pos': [37.7629734, -122.3934682],
#   'type': 'node'},
#  {'created': {'changeset': '4943615',
#               'timestamp': '2010-06-09T09:33:23Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '4'},
#   'id': '65286564',
#   'pos': [37.7193991, -122.4000287],
#   'type': 'node'},
#  {'created': {'changeset': '10853079',
#               'timestamp': '2012-03-02T22:23:52Z',
#               'uid': '28775',
#               'user': 'StellanL',
#               'version': '5'},
#   'id': '65286610',
#   'pos': [37.7519536, -122.3926171],
#   'type': 'node'},
#  {'created': {'changeset': '27601758',
#               'timestamp': '2014-12-21T04:35:13Z',
#               'uid': '371121',
#               'user': 'AndrewSnow',
#               'version': '4'},
#   'id': '65286676',
#   'pos': [37.7477814, -122.466141],
#   'type': 'node'},
#  {'created': {'changeset': '32573140',
#               'timestamp': '2015-07-12T01:24:20Z',
#               'uid': '371121',
#               'user': 'AndrewSnow',
#               'version': '3'},
#   'id': '65286779',
#   'pos': [37.7502644, -122.4632524],
#   'type': 'node'},
#  {'created': {'changeset': '33698026',
#               'timestamp': '2015-08-31T08:42:12Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '4'},
#   'id': '65286819',
#   'pos': [37.7979589, -122.4658346],
#   'type': 'node'},
#  {'created': {'changeset': '30188755',
#               'timestamp': '2015-04-13T14:14:58Z',
#               'uid': '2748195',
#               'user': 'karitotp',
#               'version': '4'},
#   'id': '65286872',
#   'pos': [37.8023329, -122.4758143],
#   'type': 'node'},
#  {'created': {'changeset': '11274865',
#               'timestamp': '2012-04-12T11:20:10Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '5'},
#   'id': '65286975',
#   'pos': [37.7207188, -122.4485208],
#   'type': 'node'},
#  {'created': {'changeset': '2102778',
#               'timestamp': '2009-08-10T21:49:23Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '65287073',
#   'pos': [37.737271, -122.386577],
#   'type': 'node'},
#  {'created': {'changeset': '37296976',
#               'timestamp': '2016-02-18T20:35:01Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '6'},
#   'id': '65287116',
#   'pos': [37.7846153, -122.4233343],
#   'type': 'node'},
#  {'created': {'changeset': '16331624',
#               'timestamp': '2013-05-28T23:32:02Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '4'},
#   'highway': 'turning_circle',
#   'id': '65287158',
#   'pos': [37.7417702, -122.4590697],
#   'type': 'node'},
#  {'created': {'changeset': '2102778',
#               'timestamp': '2009-08-10T21:49:27Z',
#               'uid': '147510',
#               'user': 'woodpeck_fixbot',
#               'version': '2'},
#   'id': '65287185',
#   'pos': [37.791709, -122.406345],
#   'type': 'node'},
#  {'created': {'changeset': '44421426',
#               'timestamp': '2016-12-15T11:57:38Z',
#               'uid': '2644101',
#               'user': 'Chetan_Gowda',
#               'version': '7'},
#   'highway': 'traffic_signals',
#   'id': '65287225',
#   'pos': [37.7779351, -122.4298029],
#   'type': 'node'},
#  {'created': {'changeset': '44419460',
#               'timestamp': '2016-12-15T10:20:07Z',
#               'uid': '2644101',
#               'user': 'Chetan_Gowda',
#               'version': '5'},
#   'highway': 'traffic_signals',
#   'id': '65287260',
#   'pos': [37.7760252, -122.4447938],
#   'type': 'node'},
#  {'created': {'changeset': '37356785',
#               'timestamp': '2016-02-21T23:20:23Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
# ...
#               'user': 'edgehillnet',
#               'version': '1'},
#   'id': '993972252',
#   'pos': [37.7424583, -122.4593175],
#   'type': 'node'},
#  {'created': {'changeset': '11111574',
#               'timestamp': '2012-03-26T22:41:19Z',
#               'uid': '116029',
#               'user': 'Gregory Arenius',
#               'version': '2'},
#   'id': '994093157',
#   'pos': [37.7504314, -122.4431021],
#   'type': 'node'},
#  {'created': {'changeset': '7313586',
#               'timestamp': '2011-02-17T14:21:33Z',
#               'uid': '116029',
#               'user': 'Gregory Arenius',
#               'version': '2'},
#   'id': '994093194',
#   'pos': [37.7469034, -122.4440369],
#   'type': 'node'},
#  {'created': {'changeset': '21308228',
#               'timestamp': '2014-03-25T16:41:11Z',
#               'uid': '1829683',
#               'user': 'Luis36995',
#               'version': '3'},
#   'id': '994093222',
#   'pos': [37.7475675, -122.4439604],
#   'type': 'node'},
#  {'created': {'changeset': '6417898',
#               'timestamp': '2010-11-20T20:50:11Z',
#               'uid': '372674',
#               'user': 'edgehillnet',
#               'version': '3'},
#   'id': '994121643',
#   'pos': [37.7466412, -122.4400187],
#   'type': 'node'},
#  {'created': {'changeset': '22146157',
#               'timestamp': '2014-05-05T12:49:45Z',
#               'uid': '1829683',
#               'user': 'Luis36995',
#               'version': '2'},
#   'id': '994211444',
#   'pos': [37.7334018, -122.4391431],
#   'type': 'node'},
#  {'created': {'changeset': '6404256',
#               'timestamp': '2010-11-19T01:16:10Z',
#               'uid': '372674',
#               'user': 'edgehillnet',
#               'version': '1'},
#   'id': '994216347',
#   'pos': [37.7519109, -122.4466662],
#   'type': 'node'},
#  {'created': {'changeset': '6404284',
#               'timestamp': '2010-11-19T01:25:44Z',
#               'uid': '372674',
#               'user': 'edgehillnet',
#               'version': '1'},
#   'id': '994232744',
#   'pos': [37.7467164, -122.4495435],
#   'type': 'node'},
#  {'created': {'changeset': '6404284',
#               'timestamp': '2010-11-19T01:25:45Z',
#               'uid': '372674',
#               'user': 'edgehillnet',
#               'version': '1'},
#   'id': '994232772',
#   'pos': [37.7467334, -122.4480737],
#   'type': 'node'},
#  {'created': {'changeset': '7313586',
#               'timestamp': '2011-02-17T14:20:55Z',
#               'uid': '116029',
#               'user': 'Gregory Arenius',
#               'version': '2'},
#   'id': '994238516',
#   'pos': [37.7511137, -122.4385932],
#   'type': 'node'},
#  {'created': {'changeset': '6404482',
#               'timestamp': '2010-11-19T03:25:32Z',
#               'uid': '372674',
#               'user': 'edgehillnet',
#               'version': '1'},
#   'id': '994294136',
#   'pos': [37.7461086, -122.4335748],
#   'type': 'node'},
#  {'created': {'changeset': '6406003',
#               'timestamp': '2010-11-19T10:54:46Z',
#               'uid': '116029',
#               'user': 'Gregory Arenius',
#               'version': '1'},
#   'id': '994490609',
#   'pos': [37.784703, -122.4074963],
#   'type': 'node'},
#  {'created': {'changeset': '6406003',
#               'timestamp': '2010-11-19T10:54:47Z',
#               'uid': '116029',
#               'user': 'Gregory Arenius',
#               'version': '1'},
#   'id': '994490651',
#   'pos': [37.7847638, -122.4074304],
#   'type': 'node'},
#  {'created': {'changeset': '6406003',
#               'timestamp': '2010-11-19T10:54:48Z',
#               'uid': '116029',
#               'user': 'Gregory Arenius',
#               'version': '1'},
#   'id': '994490689',
#   'pos': [37.784723, -122.4074453],
#   'type': 'node'},
#  {'created': {'changeset': '6665869',
#               'timestamp': '2010-12-15T09:40:55Z',
#               'uid': '116029',
#               'user': 'Gregory Arenius',
#               'version': '2'},
#   'id': '994490729',
#   'information': 'office',
#   'layer': '-1',
#   'name': 'San Francisco Visitor Information Center',
#   'pos': [37.784271, -122.4083374],
#   'tourism': 'information',
#   'type': 'node'},
#  {'created': {'changeset': '6412681',
#               'timestamp': '2010-11-20T09:46:03Z',
#               'uid': '116029',
#               'user': 'Gregory Arenius',
#               'version': '1'},
#   'id': '995847661',
#   'pos': [37.7804194, -122.4131182],
#   'type': 'node'},
#  {'created': {'changeset': '6412681',
#               'timestamp': '2010-11-20T09:46:04Z',
#               'uid': '116029',
#               'user': 'Gregory Arenius',
#               'version': '1'},
#   'id': '995847680',
#   'pos': [37.7848826, -122.4024861],
#   'type': 'node'},
#  {'created': {'changeset': '6413209',
#               'timestamp': '2010-11-20T11:12:17Z',
#               'uid': '116029',
#               'user': 'Gregory Arenius',
#               'version': '1'},
#   'id': '995938571',
#   'pos': [37.7991424, -122.398088],
#   'type': 'node'},
#  {'created': {'changeset': '22744659',
#               'timestamp': '2014-06-04T22:26:50Z',
#               'uid': '1240849',
#               'user': 'ediyes',
#               'version': '2'},
#   'id': '995938584',
#   'pos': [37.783123, -122.4779987],
#   'type': 'node'},
#  {'created': {'changeset': '22744659',
#               'timestamp': '2014-06-04T22:26:50Z',
#               'uid': '1240849',
#               'user': 'ediyes',
#               'version': '3'},
#   'id': '995938600',
#   'pos': [37.7834572, -122.478416],
#   'type': 'node'},
#  {'created': {'changeset': '22744659',
#               'timestamp': '2014-06-04T22:26:50Z',
#               'uid': '1240849',
#               'user': 'ediyes',
#               'version': '2'},
#   'id': '995938614',
#   'pos': [37.7830507, -122.4783785],
#   'type': 'node'},
#  {'created': {'changeset': '22744659',
#               'timestamp': '2014-06-04T22:26:50Z',
#               'uid': '1240849',
#               'user': 'ediyes',
#               'version': '3'},
#   'id': '995938626',
#   'pos': [37.7834534, -122.4778451],
#   'type': 'node'},
#  {'created': {'changeset': '6413209',
#               'timestamp': '2010-11-20T11:12:22Z',
#               'uid': '116029',
#               'user': 'Gregory Arenius',
#               'version': '1'},
#   'id': '995938641',
#   'pos': [37.773452, -122.4871066],
#   'type': 'node'},
#  {'created': {'changeset': '6413209',
#               'timestamp': '2010-11-20T11:12:23Z',
#               'uid': '116029',
#               'user': 'Gregory Arenius',
#               'version': '1'},
#   'id': '995938656',
#   'pos': [37.7992769, -122.398649],
#   'type': 'node'},
#  {'created': {'changeset': '11531676',
#               'timestamp': '2012-05-07T18:01:20Z',
#               'uid': '116029',
#               'user': 'Gregory Arenius',
#               'version': '3'},
#   'id': '995938671',
#   'pos': [37.7851956, -122.4783689],
#   'type': 'node'},
#  {'created': {'changeset': '7313586',
#               'timestamp': '2011-02-17T14:21:16Z',
#               'uid': '116029',
#               'user': 'Gregory Arenius',
#               'version': '3'},
#   'id': '996733687',
#   'pos': [37.7462194, -122.4393703],
#   'type': 'node'},
#  {'created': {'changeset': '6417611',
#               'timestamp': '2010-11-20T20:20:18Z',
#               'uid': '372674',
#               'user': 'edgehillnet',
#               'version': '1'},
#   'id': '996739662',
#   'pos': [37.7481428, -122.4397493],
#   'type': 'node'},
#  {'created': {'changeset': '6417611',
#               'timestamp': '2010-11-20T20:20:19Z',
#               'uid': '372674',
#               'user': 'edgehillnet',
#               'version': '1'},
#   'id': '996739688',
#   'pos': [37.7470145, -122.442217],
#   'type': 'node'},
#  {'created': {'changeset': '6418123',
#               'timestamp': '2010-11-20T21:20:18Z',
#               'uid': '372674',
#               'user': 'edgehillnet',
#               'version': '1'},
#   'id': '996857729',
#   'pos': [37.743838, -122.4406492],
#   'type': 'node'},
#  {'created': {'changeset': '10558128',
#               'timestamp': '2012-02-01T12:19:38Z',
#               'uid': '14293',
#               'user': 'KindredCoda',
#               'version': '3'},
#   'id': '996857784',
#   'pos': [37.7433994, -122.4379771],
#   'type': 'node'},
#  {'created': {'changeset': '7313586',
#               'timestamp': '2011-02-17T14:20:52Z',
#               'uid': '116029',
#               'user': 'Gregory Arenius',
#               'version': '2'},
#   'id': '996911659',
#   'pos': [37.7513968, -122.4390318],
#   'type': 'node'},
#  {'created': {'changeset': '6418444',
#               'timestamp': '2010-11-20T21:56:32Z',
#               'uid': '372674',
#               'user': 'edgehillnet',
#               'version': '1'},
#   'id': '996923486',
#   'pos': [37.7432095, -122.434964],
#   'type': 'node'},
#  {'created': {'changeset': '6418444',
#               'timestamp': '2010-11-20T22:09:42Z',
#               'uid': '372674',
#               'user': 'edgehillnet',
#               'version': '1'},
#   'id': '996937358',
#   'pos': [37.7402018, -122.4341848],
#   'type': 'node'},
#  {'created': {'changeset': '6418444',
#               'timestamp': '2010-11-20T22:09:43Z',
#               'uid': '372674',
#               'user': 'edgehillnet',
#               'version': '1'},
#   'id': '996937385',
#   'pos': [37.7417545, -122.4326238],
#   'type': 'node'},
#  {'created': {'changeset': '6418444',
#               'timestamp': '2010-11-20T22:09:44Z',
#               'uid': '372674',
#               'user': 'edgehillnet',
#               'version': '1'},
#   'id': '996937417',
#   'pos': [37.7419538, -122.4332138],
#   'type': 'node'},
#  {'created': {'changeset': '6418444',
#               'timestamp': '2010-11-20T22:09:44Z',
#               'uid': '372674',
#               'user': 'edgehillnet',
#               'version': '1'},
#   'id': '996937449',
#   'pos': [37.7419029, -122.435027],
#   'type': 'node'},
#  {'created': {'changeset': '6418621',
#               'timestamp': '2010-11-20T22:18:12Z',
#               'uid': '372674',
#               'user': 'edgehillnet',
#               'version': '1'},
#   'id': '996945082',
#   'pos': [37.7421449, -122.4360357],
#   'type': 'node'},
#  {'created': {'changeset': '6418621',
#               'timestamp': '2010-11-20T22:18:13Z',
#               'uid': '372674',
#               'user': 'edgehillnet',
#               'version': '1'},
#   'id': '996945102',
#   'pos': [37.7425521, -122.4366901],
#   'type': 'node'},
#  {'created': {'changeset': '6418621',
#               'timestamp': '2010-11-20T22:18:13Z',
#               'uid': '372674',
#               'user': 'edgehillnet',
#               'version': '1'},
#   'id': '996945119',
#   'pos': [37.7402741, -122.4360464],
#   'type': 'node'},
#  {'created': {'changeset': '6419575',
#               'timestamp': '2010-11-21T02:27:41Z',
#               'uid': '372674',
#               'user': 'edgehillnet',
#               'version': '1'},
#   'id': '997370480',
#   'pos': [37.7423577, -122.4590189],
#   'type': 'node'},
#  {'created': {'changeset': '6419575',
#               'timestamp': '2010-11-21T02:27:41Z',
#               'uid': '372674',
#               'user': 'edgehillnet',
#               'version': '1'},
#   'id': '997370504',
#   'pos': [37.7415347, -122.4584395],
#   'type': 'node'},
#  {'created': {'changeset': '6419575',
#               'timestamp': '2010-11-21T02:27:42Z',
#               'uid': '372674',
#               'user': 'edgehillnet',
#               'version': '1'},
#   'id': '997370528',
#   'pos': [37.7421817, -122.4576938],
#   'type': 'node'},
#  {'created': {'changeset': '6419575',
#               'timestamp': '2010-11-21T02:27:44Z',
#               'uid': '372674',
#               'user': 'edgehillnet',
#               'version': '1'},
#   'id': '997370575',
#   'pos': [37.7563911, -122.4626586],
#   'type': 'node'},
#  {'created': {'changeset': '21935040',
#               'timestamp': '2014-04-25T15:44:50Z',
#               'uid': '1829683',
#               'user': 'Luis36995',
#               'version': '2'},
#   'id': '997370612',
#   'pos': [37.7427276, -122.4614124],
#   'type': 'node'},
#  {'created': {'changeset': '6419610',
#               'timestamp': '2010-11-21T02:35:55Z',
#               'uid': '372674',
#               'user': 'edgehillnet',
#               'version': '1'},
#   'id': '997381213',
#   'pos': [37.7563619, -122.4626294],
#   'type': 'node'},
#  {'created': {'changeset': '6419610',
#               'timestamp': '2010-11-21T02:35:55Z',
#               'uid': '372674',
#               'user': 'edgehillnet',
#               'version': '1'},
#   'id': '997381236',
#   'pos': [37.7546187, -122.461755],
#   'type': 'node'},
#  {'created': {'changeset': '6419610',
#               'timestamp': '2010-11-21T02:35:56Z',
#               'uid': '372674',
#               'user': 'edgehillnet',
#               'version': '1'},
#   'id': '997381259',
#   'pos': [37.7529179, -122.4562887],
#   'type': 'node'},
#  {'created': {'changeset': '6419610',
#               'timestamp': '2010-11-21T02:35:57Z',
#               'uid': '372674',
#               'user': 'edgehillnet',
#               'version': '1'},
#   'id': '997381283',
#   'pos': [37.7522351, -122.4590728],
#   'type': 'node'},
#  {'created': {'changeset': '6419610',
#               'timestamp': '2010-11-21T02:35:58Z',
#               'uid': '372674',
#               'user': 'edgehillnet',
#               'version': '1'},
#   'id': '997381306',
#   'pos': [37.7538298, -122.4637184],
#   'type': 'node'},
#  {'created': {'changeset': '6419619',
#               'timestamp': '2010-11-21T02:41:27Z',
#               'uid': '192522',
#               'user': 'thecrazyknitter',
#               'version': '1'},
#   'id': '997382757',
#   'pos': [37.744377, -122.4502653],
#   'type': 'node'},
#  {'created': {'changeset': '6419619',
#               'timestamp': '2010-11-21T02:41:28Z',
#               'uid': '192522',
#               'user': 'thecrazyknitter',
#               'version': '1'},
#   'id': '997382770',
#   'pos': [37.7456708, -122.4496591],
#   'type': 'node'},
#  {'created': {'changeset': '6419619',
#               'timestamp': '2010-11-21T02:41:28Z',
#               'uid': '192522',
#               'user': 'thecrazyknitter',
#               'version': '1'},
#   'id': '997382784',
#   'pos': [37.7439274, -122.4497932],
#   'type': 'node'},
#  {'created': {'changeset': '6419619',
#               'timestamp': '2010-11-21T02:41:29Z',
#               'uid': '192522',
#               'user': 'thecrazyknitter',
#               'version': '1'},
#   'id': '997382797',
#   'pos': [37.7448436, -122.4488169],
#   'type': 'node'},
#  {'created': {'changeset': '6419619',
#               'timestamp': '2010-11-21T02:41:30Z',
#               'uid': '192522',
#               'user': 'thecrazyknitter',
#               'version': '1'},
#   'id': '997382811',
#   'pos': [37.743096, -122.4477011],
#   'type': 'node'},
#  {'created': {'changeset': '15875761',
#               'timestamp': '2013-04-26T19:06:31Z',
#               'uid': '485507',
#               'user': 'Sam Maurer',
#               'version': '2'},
#   'id': '997382962',
#   'pos': [37.7596886, -122.4476311],
#   'type': 'node'},
#  {'created': {'changeset': '17108298',
#               'timestamp': '2013-07-26T23:19:59Z',
#               'uid': '1494110',
#               'user': 'KristenK',
#               'version': '2'},
#   'id': '997411514',
#   'pos': [37.7437281, -122.4471105],
#   'type': 'node'},
#  {'created': {'changeset': '17108298',
#               'timestamp': '2013-07-26T23:19:59Z',
#               'uid': '1494110',
#               'user': 'KristenK',
#               'version': '2'},
#   'id': '997411525',
#   'pos': [37.7442994, -122.4485338],
#   'type': 'node'},
#  {'created': {'changeset': '6419778',
#               'timestamp': '2010-11-21T03:55:19Z',
#               'uid': '192522',
#               'user': 'thecrazyknitter',
#               'version': '1'},
#   'id': '997411587',
#   'pos': [37.7498757, -122.4469715],
#   'type': 'node'},
#  {'created': {'changeset': '6425409',
#               'timestamp': '2010-11-21T18:40:33Z',
#               'uid': '372674',
#               'user': 'edgehillnet',
#               'version': '1'},
#   'id': '998305067',
#   'pos': [37.7383734, -122.4293141],
#   'type': 'node'},
#  {'created': {'changeset': '6431573',
#               'timestamp': '2010-11-22T13:47:11Z',
#               'uid': '116029',
#               'user': 'Gregory Arenius',
#               'version': '1'},
#   'id': '999381682',
#   'pos': [37.8012301, -122.4341722],
#   'type': 'node'},
#  {'created'
